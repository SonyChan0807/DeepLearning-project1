# %% [markdown]
# - QUESTION : NORMALIZE AT K FOLD OR NORMALIZE WHOLE ?

# %%
import numpy as np

import torch
from torch import nn
from torch.autograd import Variable

# customized libraries
import dlc_bci as bci
import plot_lib as plib
import preprocess as prep
from nn_models import ConvNet2, LSTM
from dlc_practical_prologue import *

if __name__ == "__main__":

    # load dataset
    tr_input_org, tr_target_org = bci.load("bci", train=True, one_khz=False)
    te_input_org, te_target_org = bci.load("bci", train=False, one_khz=False)

    # create outputs with one hot encoding
    tr_target_onehot = convert_to_one_hot_labels(tr_input_org, tr_target_org)
    te_target_onehot = convert_to_one_hot_labels(te_input_org, te_target_org)
    
    # convert output to variable
    tr_target_onehot = Variable(tr_target_onehot)
    te_target_onehot = Variable(te_target_onehot)
    tr_target = Variable(tr_target_org)
    te_target = Variable(te_target_org)

    # normalization
    tr_input_org = torch.nn.functional.normalize(tr_input_org, p=2, dim=0) 
    te_input_org = torch.nn.functional.normalize(te_input_org, p=2, dim=0) 

    # Convert to 4D tensor for CNN [dataset size, number of channels, rows, cols]
    tr_input = tr_input_org[:, np.newaxis, :, :]
    te_input = te_input_org[:, np.newaxis, :, :]

    # convert input to pytorch variable
    tr_input = Variable(tr_input)
    te_input = Variable(te_input)

    # load best convolutional neural network
    # ---------------------------------------
    model = ConvNet2()
    model.load_state_dict(torch.load('models/best_conv2.pth'))

    # compute accuracy
    nb_errors = bci.compute_nb_errors(model, te_input, te_target_onehot, 10)
    print('accuracy = {:0.2f}'.format((te_input.shape[0]-nb_errors)/te_input.shape[0]))
    
    # compute accuracy of best performing LSTM
    # ---------------------------------------
    
    # rearrange data for LSTM [dataset size, timesteps, channels]
    te_input = np.transpose(te_input_org, (0,2,1))
    te_input = Variable(te_input)
    
    model = LSTM(feature_dim = 28, hidden_size=25, batch_size=10)
    model.load_state_dict(torch.load("models/best_lstm.pth"))
    
    # compute accuracy
    nb_errors = bci.compute_nb_errors(model, te_input, te_target_onehot, 10)
    print('accuracy = {:0.2f}'.format((te_input.shape[0]-nb_errors)/te_input.shape[0]))
    
    # --------------------------------------------------------------------------
    # We will train a Long-Short-Term-Memory (LSTM) architecture on the data
    # --------------------------------------------------------------------------
    
    # 1. Prepare data
    # ------------
    
    # Append training set by replicating 34 random samples since the batch size the PyTorch LSTM cannot vary
    tr_input, tr_target = prep.replicate_samples(tr_input_org, tr_target_org, 34)
        
    # Rearrange data for the LSTM to be (dataset size, timesteps, channels)
    tr_input = np.transpose(tr_input, (0,2,1))
    te_input = np.transpose(te_input_org, (0,2,1))
    
    # Prepare one-hot encoding for PyTorch computation of loss
    tr_target_onehot = convert_to_one_hot_labels(tr_input_org, tr_target)
    te_target_onehot = convert_to_one_hot_labels(te_input_org, te_target_org)
    
    # Convert to pytorch variable
    tr_input, tr_target, tr_target_onehot = Variable(tr_input), Variable(tr_target), Variable(tr_target_onehot)
    te_input, te_target, te_target_onehot = Variable(te_input), Variable(te_target_org), Variable(te_target_onehot)
    
    # 2. Begin the first phase of training
    #    where we collect the epochs that correspond to the max validation accuracy in each iteration
    # --------------------------------------------------------------------------------------------
    
    # Get the indices for 5-fold cross validation
    tr_indices, val_indices = prep.cross_validation_batch(tr_input.shape[0], 5) 
    
    # collect the epoch that corresponds to the best validation accuracy at each iterationb
    epochs = []
    
    # iterate through the disjoint sets
    for tr_ind, val_ind in zip(tr_indices, val_indices):
        
        # create LSTM
        model = LSTM(feature_dim = 28, hidden_size=25, batch_size=10)

        # train LSTM
        tr_acc, te_acc = bci.train_model_haziq(model, 
                                           tr_input[tr_ind.numpy()[None]],  tr_target[tr_ind.numpy()[None]],  tr_target_onehot[tr_ind.numpy()[None]],  10, 
                                           tr_input[val_ind.numpy()[None]], tr_target[val_ind.numpy()[None]], tr_target_onehot[val_ind.numpy()[None]], 10, 
                                           200)
    
        # get epoch corresponding to the best validation accuracy
        epoch_max_val_acc = np.argmax(te_acc)

        # show best performing model
        print('tr acc {:.2f}% val acc {:.2f}% at epoch {:d}'.format(tr_acc[epoch_max_val_acc]*100, 
                                                                    te_acc[epoch_max_val_acc]*100,
                                                                    epoch_max_val_acc))

        epochs.append(epoch_max_val_acc)

    # 3. Begin the second and final phase of training
    #   where we train the model with the average of the epochs collected beforehand
    # --------------------------------------------------------------------------------------------
    
    # create LSTM
    model = LSTM(feature_dim = 28, hidden_size=25, batch_size=10)

    # train LSTM
    tr_acc, te_acc = bci.train_model_haziq(model, 
                                      tr_input,  tr_target,  tr_target_onehot,  10, 
                                      te_input,  te_target,  te_target_onehot,  10, 
                                      int(np.average(epochs)))
    
    # 4. Compute accuracy of final model
    # -------------------------------
    nb_errors = bci.compute_nb_errors(model, te_input, te_target_onehot, 10)
    print('accuracy = {:0.2f}'.format((te_input.shape[0]-nb_errors)/te_input.shape[0]))
# Out:
# accuracy = 0.85
# accuracy = 0.77
# epoch 0 tr loss 19.41 val loss 4.86 tr acc 0.521429 val acc 0.485714
# epoch 1 tr loss 19.36 val loss 4.85 tr acc 0.521429 val acc 0.528571
# epoch 2 tr loss 19.34 val loss 4.85 tr acc 0.578571 val acc 0.485714
# epoch 3 tr loss 19.31 val loss 4.85 tr acc 0.571429 val acc 0.528571
# epoch 4 tr loss 19.29 val loss 4.85 tr acc 0.553571 val acc 0.542857
# epoch 5 tr loss 19.26 val loss 4.85 tr acc 0.557143 val acc 0.542857
# epoch 6 tr loss 19.21 val loss 4.85 tr acc 0.557143 val acc 0.514286
# epoch 7 tr loss 19.13 val loss 4.90 tr acc 0.560714 val acc 0.528571
# epoch 8 tr loss 19.11 val loss 4.89 tr acc 0.575000 val acc 0.571429
# epoch 9 tr loss 18.98 val loss 4.92 tr acc 0.578571 val acc 0.571429
# epoch 10 tr loss 18.92 val loss 4.94 tr acc 0.589286 val acc 0.557143
# epoch 11 tr loss 18.88 val loss 4.99 tr acc 0.582143 val acc 0.571429
# epoch 12 tr loss 19.20 val loss 4.83 tr acc 0.571429 val acc 0.485714
# epoch 13 tr loss 19.03 val loss 4.81 tr acc 0.596429 val acc 0.557143
# epoch 14 tr loss 18.96 val loss 4.80 tr acc 0.589286 val acc 0.557143
# epoch 15 tr loss 18.89 val loss 4.81 tr acc 0.582143 val acc 0.571429
# epoch 16 tr loss 18.80 val loss 4.82 tr acc 0.582143 val acc 0.557143
# epoch 17 tr loss 18.67 val loss 4.86 tr acc 0.607143 val acc 0.557143
# epoch 18 tr loss 18.55 val loss 4.88 tr acc 0.628571 val acc 0.542857
# epoch 19 tr loss 18.44 val loss 4.90 tr acc 0.646429 val acc 0.600000
# epoch 20 tr loss 18.37 val loss 4.81 tr acc 0.660714 val acc 0.628571
# epoch 21 tr loss 18.14 val loss 4.77 tr acc 0.667857 val acc 0.600000
# epoch 22 tr loss 18.09 val loss 4.64 tr acc 0.657143 val acc 0.600000
# epoch 23 tr loss 17.97 val loss 4.76 tr acc 0.671429 val acc 0.614286
# epoch 24 tr loss 17.87 val loss 4.88 tr acc 0.664286 val acc 0.671429
# epoch 25 tr loss 17.88 val loss 4.76 tr acc 0.675000 val acc 0.671429
# epoch 26 tr loss 17.32 val loss 4.75 tr acc 0.689286 val acc 0.685714
# epoch 27 tr loss 17.73 val loss 4.65 tr acc 0.639286 val acc 0.571429
# epoch 28 tr loss 18.10 val loss 4.74 tr acc 0.671429 val acc 0.685714
# epoch 29 tr loss 17.70 val loss 4.67 tr acc 0.703571 val acc 0.614286
# epoch 30 tr loss 17.26 val loss 4.55 tr acc 0.735714 val acc 0.614286
# epoch 31 tr loss 16.75 val loss 4.63 tr acc 0.735714 val acc 0.671429
# epoch 32 tr loss 16.32 val loss 4.36 tr acc 0.732143 val acc 0.700000
# epoch 33 tr loss 16.30 val loss 4.96 tr acc 0.635714 val acc 0.528571
# epoch 34 tr loss 17.68 val loss 4.67 tr acc 0.739286 val acc 0.671429
# epoch 35 tr loss 15.87 val loss 4.69 tr acc 0.664286 val acc 0.628571
# epoch 36 tr loss 15.29 val loss 4.54 tr acc 0.710714 val acc 0.614286
# epoch 37 tr loss 14.91 val loss 4.57 tr acc 0.739286 val acc 0.628571
# epoch 38 tr loss 14.59 val loss 4.61 tr acc 0.746429 val acc 0.657143
# epoch 39 tr loss 17.92 val loss 4.52 tr acc 0.750000 val acc 0.657143
# epoch 40 tr loss 15.58 val loss 4.63 tr acc 0.767857 val acc 0.642857
# epoch 41 tr loss 14.28 val loss 4.55 tr acc 0.785714 val acc 0.642857
# epoch 42 tr loss 14.18 val loss 4.46 tr acc 0.800000 val acc 0.642857
# epoch 43 tr loss 13.63 val loss 4.33 tr acc 0.789286 val acc 0.685714
# epoch 44 tr loss 13.80 val loss 4.33 tr acc 0.782143 val acc 0.657143
# epoch 45 tr loss 13.44 val loss 4.37 tr acc 0.810714 val acc 0.685714
# epoch 46 tr loss 13.16 val loss 4.37 tr acc 0.810714 val acc 0.671429
# epoch 47 tr loss 13.19 val loss 4.31 tr acc 0.817857 val acc 0.685714
# epoch 48 tr loss 13.48 val loss 4.27 tr acc 0.796429 val acc 0.714286
# epoch 49 tr loss 12.84 val loss 4.32 tr acc 0.825000 val acc 0.714286
# epoch 50 tr loss 13.60 val loss 4.49 tr acc 0.796429 val acc 0.700000
# epoch 51 tr loss 12.88 val loss 4.20 tr acc 0.803571 val acc 0.714286
# epoch 52 tr loss 12.67 val loss 4.41 tr acc 0.782143 val acc 0.742857
# epoch 53 tr loss 14.56 val loss 4.30 tr acc 0.800000 val acc 0.700000
# epoch 54 tr loss 12.43 val loss 4.19 tr acc 0.800000 val acc 0.728571
# epoch 55 tr loss 12.43 val loss 4.21 tr acc 0.825000 val acc 0.728571
# epoch 56 tr loss 11.88 val loss 4.36 tr acc 0.832143 val acc 0.700000
# epoch 57 tr loss 12.00 val loss 4.23 tr acc 0.839286 val acc 0.714286
# epoch 58 tr loss 12.08 val loss 4.12 tr acc 0.828571 val acc 0.728571
# epoch 59 tr loss 11.72 val loss 4.48 tr acc 0.846429 val acc 0.714286
# epoch 60 tr loss 11.79 val loss 4.36 tr acc 0.832143 val acc 0.685714
# epoch 61 tr loss 11.32 val loss 4.38 tr acc 0.835714 val acc 0.685714
# epoch 62 tr loss 10.96 val loss 4.22 tr acc 0.850000 val acc 0.700000
# epoch 63 tr loss 12.21 val loss 4.11 tr acc 0.839286 val acc 0.657143
# epoch 64 tr loss 10.84 val loss 4.32 tr acc 0.846429 val acc 0.700000
# epoch 65 tr loss 11.12 val loss 4.17 tr acc 0.846429 val acc 0.742857
# epoch 66 tr loss 10.81 val loss 4.17 tr acc 0.825000 val acc 0.714286
# epoch 67 tr loss 10.76 val loss 4.16 tr acc 0.835714 val acc 0.728571
# epoch 68 tr loss 10.95 val loss 3.99 tr acc 0.828571 val acc 0.771429
# epoch 69 tr loss 10.52 val loss 4.12 tr acc 0.832143 val acc 0.700000
# epoch 70 tr loss 10.35 val loss 4.09 tr acc 0.821429 val acc 0.728571
# epoch 71 tr loss 11.07 val loss 4.23 tr acc 0.807143 val acc 0.714286
# epoch 72 tr loss 11.19 val loss 3.90 tr acc 0.839286 val acc 0.685714
# epoch 73 tr loss 10.73 val loss 4.09 tr acc 0.853571 val acc 0.714286
# epoch 74 tr loss 10.63 val loss 4.07 tr acc 0.835714 val acc 0.700000
# epoch 75 tr loss 10.57 val loss 4.15 tr acc 0.857143 val acc 0.700000
# epoch 76 tr loss 10.74 val loss 4.10 tr acc 0.846429 val acc 0.714286
# epoch 77 tr loss 10.27 val loss 4.29 tr acc 0.846429 val acc 0.700000
# epoch 78 tr loss 10.93 val loss 4.03 tr acc 0.853571 val acc 0.728571
# epoch 79 tr loss 9.89 val loss 4.24 tr acc 0.835714 val acc 0.700000
# epoch 80 tr loss 11.91 val loss 3.83 tr acc 0.825000 val acc 0.657143
# epoch 81 tr loss 10.14 val loss 4.07 tr acc 0.839286 val acc 0.714286
# epoch 82 tr loss 10.26 val loss 4.24 tr acc 0.850000 val acc 0.714286
# epoch 83 tr loss 10.94 val loss 4.01 tr acc 0.828571 val acc 0.671429
# epoch 84 tr loss 9.75 val loss 4.25 tr acc 0.850000 val acc 0.700000
# epoch 85 tr loss 10.44 val loss 4.03 tr acc 0.871429 val acc 0.714286
# epoch 86 tr loss 10.09 val loss 4.14 tr acc 0.860714 val acc 0.714286
# epoch 87 tr loss 9.72 val loss 4.27 tr acc 0.864286 val acc 0.714286
# epoch 88 tr loss 10.54 val loss 4.09 tr acc 0.875000 val acc 0.714286
# epoch 89 tr loss 9.26 val loss 4.29 tr acc 0.853571 val acc 0.714286
# epoch 90 tr loss 10.65 val loss 4.12 tr acc 0.871429 val acc 0.714286
# epoch 91 tr loss 9.10 val loss 4.28 tr acc 0.860714 val acc 0.728571
# epoch 92 tr loss 10.60 val loss 4.10 tr acc 0.867857 val acc 0.700000
# epoch 93 tr loss 9.06 val loss 4.26 tr acc 0.857143 val acc 0.714286
# epoch 94 tr loss 10.77 val loss 3.93 tr acc 0.832143 val acc 0.671429
# epoch 95 tr loss 9.21 val loss 4.17 tr acc 0.860714 val acc 0.714286
# epoch 96 tr loss 10.19 val loss 3.88 tr acc 0.871429 val acc 0.714286
# epoch 97 tr loss 9.60 val loss 4.06 tr acc 0.878571 val acc 0.728571
# epoch 98 tr loss 9.36 val loss 4.14 tr acc 0.885714 val acc 0.728571
# epoch 99 tr loss 9.65 val loss 4.14 tr acc 0.889286 val acc 0.728571
# epoch 100 tr loss 9.20 val loss 4.26 tr acc 0.878571 val acc 0.714286
# epoch 101 tr loss 9.40 val loss 4.19 tr acc 0.889286 val acc 0.714286
# epoch 102 tr loss 9.24 val loss 4.06 tr acc 0.889286 val acc 0.714286
# epoch 103 tr loss 9.28 val loss 3.94 tr acc 0.885714 val acc 0.728571
# epoch 104 tr loss 9.26 val loss 3.94 tr acc 0.875000 val acc 0.728571
# epoch 105 tr loss 9.50 val loss 3.89 tr acc 0.875000 val acc 0.728571
# epoch 106 tr loss 9.18 val loss 3.81 tr acc 0.885714 val acc 0.742857
# epoch 107 tr loss 9.60 val loss 3.78 tr acc 0.882143 val acc 0.728571
# epoch 108 tr loss 9.06 val loss 3.84 tr acc 0.875000 val acc 0.728571
# epoch 109 tr loss 8.94 val loss 3.92 tr acc 0.889286 val acc 0.728571
# epoch 110 tr loss 8.81 val loss 4.03 tr acc 0.889286 val acc 0.700000
# epoch 111 tr loss 8.81 val loss 4.11 tr acc 0.885714 val acc 0.714286
# epoch 112 tr loss 8.64 val loss 4.10 tr acc 0.885714 val acc 0.714286
# epoch 113 tr loss 8.50 val loss 3.91 tr acc 0.896429 val acc 0.728571
# epoch 114 tr loss 8.54 val loss 3.67 tr acc 0.889286 val acc 0.742857
# epoch 115 tr loss 8.84 val loss 3.50 tr acc 0.875000 val acc 0.742857
# epoch 116 tr loss 8.99 val loss 3.53 tr acc 0.864286 val acc 0.800000
# epoch 117 tr loss 9.18 val loss 3.53 tr acc 0.882143 val acc 0.757143
# epoch 118 tr loss 10.16 val loss 3.30 tr acc 0.860714 val acc 0.757143
# epoch 119 tr loss 9.25 val loss 3.58 tr acc 0.857143 val acc 0.742857
# epoch 120 tr loss 8.97 val loss 3.81 tr acc 0.875000 val acc 0.757143
# epoch 121 tr loss 9.16 val loss 3.93 tr acc 0.889286 val acc 0.757143
# epoch 122 tr loss 8.61 val loss 4.05 tr acc 0.882143 val acc 0.728571
# epoch 123 tr loss 8.36 val loss 4.11 tr acc 0.885714 val acc 0.728571
# epoch 124 tr loss 8.44 val loss 4.06 tr acc 0.889286 val acc 0.728571
# epoch 125 tr loss 8.50 val loss 3.90 tr acc 0.892857 val acc 0.742857
# epoch 126 tr loss 8.32 val loss 3.64 tr acc 0.882143 val acc 0.728571
# epoch 127 tr loss 8.44 val loss 3.40 tr acc 0.871429 val acc 0.771429
# epoch 128 tr loss 8.90 val loss 3.55 tr acc 0.860714 val acc 0.771429
# epoch 129 tr loss 8.99 val loss 3.83 tr acc 0.875000 val acc 0.757143
# epoch 130 tr loss 8.56 val loss 3.71 tr acc 0.871429 val acc 0.742857
# epoch 131 tr loss 8.26 val loss 3.77 tr acc 0.885714 val acc 0.742857
# epoch 132 tr loss 8.56 val loss 3.71 tr acc 0.896429 val acc 0.742857
# epoch 133 tr loss 8.51 val loss 3.53 tr acc 0.871429 val acc 0.728571
# epoch 134 tr loss 8.14 val loss 3.65 tr acc 0.867857 val acc 0.757143
# epoch 135 tr loss 8.49 val loss 3.93 tr acc 0.878571 val acc 0.742857
# epoch 136 tr loss 8.13 val loss 4.04 tr acc 0.882143 val acc 0.714286
# epoch 137 tr loss 7.95 val loss 4.01 tr acc 0.885714 val acc 0.728571
# epoch 138 tr loss 8.22 val loss 4.06 tr acc 0.889286 val acc 0.728571
# epoch 139 tr loss 8.62 val loss 4.18 tr acc 0.885714 val acc 0.757143
# epoch 140 tr loss 8.79 val loss 4.13 tr acc 0.864286 val acc 0.714286
# epoch 141 tr loss 8.50 val loss 4.04 tr acc 0.832143 val acc 0.742857
# epoch 142 tr loss 11.07 val loss 3.53 tr acc 0.821429 val acc 0.757143
# epoch 143 tr loss 9.98 val loss 3.74 tr acc 0.857143 val acc 0.742857
# epoch 144 tr loss 9.38 val loss 3.69 tr acc 0.885714 val acc 0.771429
# epoch 145 tr loss 8.56 val loss 3.43 tr acc 0.907143 val acc 0.785714
# epoch 146 tr loss 8.94 val loss 3.68 tr acc 0.892857 val acc 0.742857
# epoch 147 tr loss 8.94 val loss 3.58 tr acc 0.882143 val acc 0.742857
# epoch 148 tr loss 8.59 val loss 3.64 tr acc 0.896429 val acc 0.742857
# epoch 149 tr loss 8.36 val loss 3.53 tr acc 0.907143 val acc 0.785714
# epoch 150 tr loss 8.53 val loss 3.59 tr acc 0.900000 val acc 0.742857
# epoch 151 tr loss 7.77 val loss 3.60 tr acc 0.903571 val acc 0.742857
# epoch 152 tr loss 7.98 val loss 3.73 tr acc 0.885714 val acc 0.742857
# epoch 153 tr loss 8.18 val loss 3.63 tr acc 0.900000 val acc 0.728571
# epoch 154 tr loss 8.09 val loss 3.63 tr acc 0.900000 val acc 0.757143
# epoch 155 tr loss 8.17 val loss 3.67 tr acc 0.885714 val acc 0.757143
# epoch 156 tr loss 8.25 val loss 3.71 tr acc 0.892857 val acc 0.757143
# epoch 157 tr loss 8.22 val loss 3.66 tr acc 0.878571 val acc 0.757143
# epoch 158 tr loss 8.15 val loss 3.75 tr acc 0.885714 val acc 0.757143
# epoch 159 tr loss 7.90 val loss 3.77 tr acc 0.889286 val acc 0.757143
# epoch 160 tr loss 7.62 val loss 3.76 tr acc 0.885714 val acc 0.785714
# epoch 161 tr loss 8.19 val loss 3.76 tr acc 0.878571 val acc 0.785714
# epoch 162 tr loss 10.27 val loss 4.41 tr acc 0.846429 val acc 0.714286
# epoch 163 tr loss 9.35 val loss 3.41 tr acc 0.857143 val acc 0.728571
# epoch 164 tr loss 9.35 val loss 3.75 tr acc 0.857143 val acc 0.757143
# epoch 165 tr loss 9.30 val loss 3.57 tr acc 0.889286 val acc 0.728571
# epoch 166 tr loss 7.63 val loss 3.42 tr acc 0.889286 val acc 0.742857
# epoch 167 tr loss 7.81 val loss 3.53 tr acc 0.896429 val acc 0.771429
# epoch 168 tr loss 7.90 val loss 3.73 tr acc 0.896429 val acc 0.757143
# epoch 169 tr loss 7.71 val loss 3.76 tr acc 0.900000 val acc 0.742857
# epoch 170 tr loss 7.49 val loss 3.68 tr acc 0.903571 val acc 0.742857
# epoch 171 tr loss 7.26 val loss 3.76 tr acc 0.903571 val acc 0.742857
# epoch 172 tr loss 7.29 val loss 3.70 tr acc 0.907143 val acc 0.757143
# epoch 173 tr loss 7.35 val loss 3.79 tr acc 0.903571 val acc 0.742857
# epoch 174 tr loss 6.96 val loss 3.72 tr acc 0.903571 val acc 0.757143
# epoch 175 tr loss 7.25 val loss 3.80 tr acc 0.914286 val acc 0.757143
# epoch 176 tr loss 8.15 val loss 3.98 tr acc 0.875000 val acc 0.814286
# epoch 177 tr loss 7.76 val loss 3.51 tr acc 0.900000 val acc 0.800000
# epoch 178 tr loss 7.77 val loss 4.10 tr acc 0.878571 val acc 0.757143
# epoch 179 tr loss 8.78 val loss 3.96 tr acc 0.878571 val acc 0.771429
# epoch 180 tr loss 7.82 val loss 3.99 tr acc 0.910714 val acc 0.757143
# epoch 181 tr loss 10.94 val loss 3.60 tr acc 0.857143 val acc 0.785714
# epoch 182 tr loss 8.92 val loss 3.28 tr acc 0.867857 val acc 0.785714
# epoch 183 tr loss 8.93 val loss 3.99 tr acc 0.853571 val acc 0.785714
# epoch 184 tr loss 9.57 val loss 3.35 tr acc 0.875000 val acc 0.785714
# epoch 185 tr loss 8.10 val loss 3.37 tr acc 0.889286 val acc 0.785714
# epoch 186 tr loss 7.78 val loss 3.49 tr acc 0.875000 val acc 0.800000
# epoch 187 tr loss 7.86 val loss 3.44 tr acc 0.882143 val acc 0.785714
# epoch 188 tr loss 7.68 val loss 3.46 tr acc 0.878571 val acc 0.771429
# epoch 189 tr loss 7.53 val loss 3.47 tr acc 0.882143 val acc 0.771429
# epoch 190 tr loss 7.55 val loss 3.62 tr acc 0.878571 val acc 0.771429
# epoch 191 tr loss 7.39 val loss 3.56 tr acc 0.892857 val acc 0.785714
# epoch 192 tr loss 7.32 val loss 3.65 tr acc 0.892857 val acc 0.785714
# epoch 193 tr loss 8.42 val loss 4.63 tr acc 0.864286 val acc 0.757143
# epoch 194 tr loss 8.40 val loss 3.44 tr acc 0.925000 val acc 0.828571
# epoch 195 tr loss 6.93 val loss 3.69 tr acc 0.917857 val acc 0.785714
# epoch 196 tr loss 7.05 val loss 3.71 tr acc 0.867857 val acc 0.800000
# epoch 197 tr loss 6.96 val loss 3.62 tr acc 0.917857 val acc 0.800000
# epoch 198 tr loss 7.56 val loss 3.26 tr acc 0.885714 val acc 0.800000
# epoch 199 tr loss 7.02 val loss 3.73 tr acc 0.903571 val acc 0.771429
# tr acc 92.50% val acc 82.86% at epoch 194
# epoch 0 tr loss 19.51 val loss 4.86 tr acc 0.507143 val acc 0.500000
# epoch 1 tr loss 19.42 val loss 4.85 tr acc 0.510714 val acc 0.500000
# epoch 2 tr loss 19.39 val loss 4.84 tr acc 0.553571 val acc 0.557143
# epoch 3 tr loss 19.37 val loss 4.84 tr acc 0.557143 val acc 0.542857
# epoch 4 tr loss 19.35 val loss 4.84 tr acc 0.542857 val acc 0.557143
# epoch 5 tr loss 19.33 val loss 4.83 tr acc 0.557143 val acc 0.571429
# epoch 6 tr loss 19.30 val loss 4.83 tr acc 0.557143 val acc 0.571429
# epoch 7 tr loss 19.28 val loss 4.82 tr acc 0.557143 val acc 0.585714
# epoch 8 tr loss 19.26 val loss 4.81 tr acc 0.564286 val acc 0.585714
# epoch 9 tr loss 19.23 val loss 4.79 tr acc 0.557143 val acc 0.571429
# epoch 10 tr loss 19.20 val loss 4.78 tr acc 0.560714 val acc 0.571429
# epoch 11 tr loss 19.16 val loss 4.76 tr acc 0.564286 val acc 0.585714
# epoch 12 tr loss 19.12 val loss 4.74 tr acc 0.567857 val acc 0.585714
# epoch 13 tr loss 19.06 val loss 4.71 tr acc 0.585714 val acc 0.600000
# epoch 14 tr loss 18.99 val loss 4.68 tr acc 0.592857 val acc 0.628571
# epoch 15 tr loss 18.90 val loss 4.65 tr acc 0.632143 val acc 0.628571
# epoch 16 tr loss 18.75 val loss 4.61 tr acc 0.667857 val acc 0.685714
# epoch 17 tr loss 18.67 val loss 4.59 tr acc 0.671429 val acc 0.700000
# epoch 18 tr loss 18.49 val loss 4.55 tr acc 0.689286 val acc 0.657143
# epoch 19 tr loss 18.35 val loss 4.54 tr acc 0.685714 val acc 0.628571
# epoch 20 tr loss 18.32 val loss 4.51 tr acc 0.710714 val acc 0.671429
# epoch 21 tr loss 18.11 val loss 4.49 tr acc 0.692857 val acc 0.614286
# epoch 22 tr loss 17.95 val loss 4.49 tr acc 0.696429 val acc 0.600000
# epoch 23 tr loss 17.88 val loss 4.47 tr acc 0.700000 val acc 0.600000
# epoch 24 tr loss 17.72 val loss 4.45 tr acc 0.710714 val acc 0.628571
# epoch 25 tr loss 17.54 val loss 4.44 tr acc 0.689286 val acc 0.614286
# epoch 26 tr loss 17.38 val loss 4.42 tr acc 0.692857 val acc 0.614286
# epoch 27 tr loss 17.21 val loss 4.41 tr acc 0.703571 val acc 0.628571
# epoch 28 tr loss 17.05 val loss 4.39 tr acc 0.714286 val acc 0.614286
# epoch 29 tr loss 16.90 val loss 4.37 tr acc 0.714286 val acc 0.614286
# epoch 30 tr loss 16.74 val loss 4.36 tr acc 0.703571 val acc 0.628571
# epoch 31 tr loss 16.54 val loss 4.34 tr acc 0.700000 val acc 0.628571
# epoch 32 tr loss 16.29 val loss 4.31 tr acc 0.703571 val acc 0.657143
# epoch 33 tr loss 16.03 val loss 4.23 tr acc 0.728571 val acc 0.671429
# epoch 34 tr loss 15.69 val loss 4.17 tr acc 0.728571 val acc 0.642857
# epoch 35 tr loss 15.40 val loss 4.02 tr acc 0.742857 val acc 0.657143
# epoch 36 tr loss 15.09 val loss 4.03 tr acc 0.739286 val acc 0.657143
# epoch 37 tr loss 14.88 val loss 4.45 tr acc 0.692857 val acc 0.628571
# epoch 38 tr loss 16.39 val loss 4.05 tr acc 0.728571 val acc 0.728571
# epoch 39 tr loss 15.10 val loss 4.10 tr acc 0.721429 val acc 0.657143
# epoch 40 tr loss 14.73 val loss 3.66 tr acc 0.750000 val acc 0.742857
# epoch 41 tr loss 14.54 val loss 3.88 tr acc 0.735714 val acc 0.700000
# epoch 42 tr loss 14.05 val loss 3.61 tr acc 0.753571 val acc 0.757143
# epoch 43 tr loss 14.76 val loss 3.70 tr acc 0.782143 val acc 0.742857
# epoch 44 tr loss 14.23 val loss 3.71 tr acc 0.792857 val acc 0.742857
# epoch 45 tr loss 13.21 val loss 3.78 tr acc 0.760714 val acc 0.771429
# epoch 46 tr loss 13.12 val loss 3.83 tr acc 0.750000 val acc 0.728571
# epoch 47 tr loss 14.01 val loss 4.08 tr acc 0.739286 val acc 0.657143
# epoch 48 tr loss 15.37 val loss 3.73 tr acc 0.810714 val acc 0.757143
# epoch 49 tr loss 13.29 val loss 3.70 tr acc 0.757143 val acc 0.728571
# epoch 50 tr loss 13.04 val loss 3.86 tr acc 0.750000 val acc 0.700000
# epoch 51 tr loss 13.39 val loss 3.64 tr acc 0.782143 val acc 0.757143
# epoch 52 tr loss 13.32 val loss 3.61 tr acc 0.757143 val acc 0.757143
# epoch 53 tr loss 13.14 val loss 4.06 tr acc 0.760714 val acc 0.657143
# epoch 54 tr loss 13.99 val loss 3.68 tr acc 0.750000 val acc 0.742857
# epoch 55 tr loss 12.46 val loss 3.46 tr acc 0.782143 val acc 0.785714
# epoch 56 tr loss 11.97 val loss 3.48 tr acc 0.810714 val acc 0.800000
# epoch 57 tr loss 12.66 val loss 3.66 tr acc 0.782143 val acc 0.771429
# epoch 58 tr loss 11.74 val loss 3.55 tr acc 0.800000 val acc 0.800000
# epoch 59 tr loss 12.63 val loss 3.93 tr acc 0.753571 val acc 0.657143
# epoch 60 tr loss 11.87 val loss 3.81 tr acc 0.800000 val acc 0.785714
# epoch 61 tr loss 11.81 val loss 3.71 tr acc 0.792857 val acc 0.757143
# epoch 62 tr loss 11.91 val loss 3.58 tr acc 0.771429 val acc 0.728571
# epoch 63 tr loss 13.13 val loss 3.66 tr acc 0.782143 val acc 0.742857
# epoch 64 tr loss 11.68 val loss 3.61 tr acc 0.807143 val acc 0.785714
# epoch 65 tr loss 10.86 val loss 3.68 tr acc 0.775000 val acc 0.757143
# epoch 66 tr loss 11.23 val loss 4.03 tr acc 0.764286 val acc 0.657143
# epoch 67 tr loss 14.96 val loss 3.69 tr acc 0.782143 val acc 0.742857
# epoch 68 tr loss 13.37 val loss 3.35 tr acc 0.810714 val acc 0.771429
# epoch 69 tr loss 11.81 val loss 3.60 tr acc 0.807143 val acc 0.742857
# epoch 70 tr loss 10.56 val loss 3.52 tr acc 0.817857 val acc 0.828571
# epoch 71 tr loss 10.53 val loss 3.48 tr acc 0.807143 val acc 0.800000
# epoch 72 tr loss 10.51 val loss 3.50 tr acc 0.810714 val acc 0.785714
# epoch 73 tr loss 10.53 val loss 3.56 tr acc 0.803571 val acc 0.771429
# epoch 74 tr loss 10.78 val loss 3.55 tr acc 0.821429 val acc 0.814286
# epoch 75 tr loss 10.40 val loss 3.71 tr acc 0.803571 val acc 0.757143
# epoch 76 tr loss 10.05 val loss 3.67 tr acc 0.821429 val acc 0.800000
# epoch 77 tr loss 10.00 val loss 3.85 tr acc 0.807143 val acc 0.757143
# epoch 78 tr loss 10.34 val loss 3.41 tr acc 0.814286 val acc 0.800000
# epoch 79 tr loss 10.42 val loss 3.55 tr acc 0.825000 val acc 0.814286
# epoch 80 tr loss 10.72 val loss 3.66 tr acc 0.828571 val acc 0.771429
# epoch 81 tr loss 13.00 val loss 3.39 tr acc 0.821429 val acc 0.800000
# epoch 82 tr loss 10.09 val loss 3.63 tr acc 0.821429 val acc 0.771429
# epoch 83 tr loss 10.29 val loss 3.67 tr acc 0.817857 val acc 0.800000
# epoch 84 tr loss 10.72 val loss 3.64 tr acc 0.839286 val acc 0.800000
# epoch 85 tr loss 10.03 val loss 3.57 tr acc 0.814286 val acc 0.785714
# epoch 86 tr loss 10.06 val loss 3.44 tr acc 0.842857 val acc 0.828571
# epoch 87 tr loss 9.93 val loss 3.61 tr acc 0.860714 val acc 0.800000
# epoch 88 tr loss 9.26 val loss 3.65 tr acc 0.853571 val acc 0.800000
# epoch 89 tr loss 9.32 val loss 4.83 tr acc 0.785714 val acc 0.742857
# epoch 90 tr loss 9.97 val loss 3.86 tr acc 0.817857 val acc 0.771429
# epoch 91 tr loss 9.57 val loss 4.10 tr acc 0.817857 val acc 0.714286
# epoch 92 tr loss 8.98 val loss 3.61 tr acc 0.850000 val acc 0.800000
# epoch 93 tr loss 9.31 val loss 4.68 tr acc 0.796429 val acc 0.714286
# epoch 94 tr loss 8.94 val loss 3.77 tr acc 0.846429 val acc 0.785714
# epoch 95 tr loss 8.81 val loss 4.60 tr acc 0.814286 val acc 0.714286
# epoch 96 tr loss 9.76 val loss 3.63 tr acc 0.853571 val acc 0.785714
# epoch 97 tr loss 9.03 val loss 3.97 tr acc 0.846429 val acc 0.771429
# epoch 98 tr loss 8.56 val loss 3.62 tr acc 0.871429 val acc 0.800000
# epoch 99 tr loss 8.70 val loss 4.11 tr acc 0.853571 val acc 0.785714
# epoch 100 tr loss 8.47 val loss 3.95 tr acc 0.867857 val acc 0.785714
# epoch 101 tr loss 8.56 val loss 4.28 tr acc 0.846429 val acc 0.771429
# epoch 102 tr loss 8.54 val loss 4.03 tr acc 0.857143 val acc 0.771429
# epoch 103 tr loss 8.72 val loss 4.20 tr acc 0.853571 val acc 0.785714
# epoch 104 tr loss 8.21 val loss 3.82 tr acc 0.864286 val acc 0.785714
# epoch 105 tr loss 8.27 val loss 4.03 tr acc 0.864286 val acc 0.785714
# epoch 106 tr loss 8.37 val loss 3.92 tr acc 0.850000 val acc 0.771429
# epoch 107 tr loss 8.24 val loss 3.66 tr acc 0.875000 val acc 0.814286
# epoch 108 tr loss 8.29 val loss 3.71 tr acc 0.871429 val acc 0.814286
# epoch 109 tr loss 8.06 val loss 3.69 tr acc 0.864286 val acc 0.814286
# epoch 110 tr loss 8.04 val loss 3.64 tr acc 0.875000 val acc 0.814286
# epoch 111 tr loss 9.13 val loss 3.69 tr acc 0.867857 val acc 0.800000
# epoch 112 tr loss 8.23 val loss 3.72 tr acc 0.882143 val acc 0.814286
# epoch 113 tr loss 8.22 val loss 3.71 tr acc 0.867857 val acc 0.814286
# epoch 114 tr loss 11.57 val loss 3.69 tr acc 0.782143 val acc 0.742857
# epoch 115 tr loss 11.22 val loss 3.41 tr acc 0.853571 val acc 0.814286
# epoch 116 tr loss 10.89 val loss 3.17 tr acc 0.857143 val acc 0.800000
# epoch 117 tr loss 10.96 val loss 3.30 tr acc 0.853571 val acc 0.771429
# epoch 118 tr loss 9.98 val loss 3.29 tr acc 0.864286 val acc 0.828571
# epoch 119 tr loss 10.28 val loss 3.37 tr acc 0.835714 val acc 0.800000
# epoch 120 tr loss 9.55 val loss 3.53 tr acc 0.846429 val acc 0.757143
# epoch 121 tr loss 9.04 val loss 3.63 tr acc 0.857143 val acc 0.814286
# epoch 122 tr loss 11.21 val loss 3.65 tr acc 0.832143 val acc 0.742857
# epoch 123 tr loss 10.37 val loss 3.57 tr acc 0.835714 val acc 0.771429
# epoch 124 tr loss 9.43 val loss 3.44 tr acc 0.867857 val acc 0.785714
# epoch 125 tr loss 8.61 val loss 3.65 tr acc 0.860714 val acc 0.771429
# epoch 126 tr loss 8.53 val loss 3.74 tr acc 0.846429 val acc 0.742857
# epoch 127 tr loss 10.45 val loss 3.96 tr acc 0.846429 val acc 0.728571
# epoch 128 tr loss 9.91 val loss 3.28 tr acc 0.857143 val acc 0.814286
# epoch 129 tr loss 9.88 val loss 3.33 tr acc 0.832143 val acc 0.771429
# epoch 130 tr loss 10.29 val loss 3.40 tr acc 0.814286 val acc 0.814286
# epoch 131 tr loss 11.27 val loss 3.66 tr acc 0.825000 val acc 0.714286
# epoch 132 tr loss 10.70 val loss 3.14 tr acc 0.864286 val acc 0.857143
# epoch 133 tr loss 8.54 val loss 3.52 tr acc 0.860714 val acc 0.814286
# epoch 134 tr loss 9.63 val loss 3.45 tr acc 0.860714 val acc 0.785714
# epoch 135 tr loss 9.07 val loss 3.69 tr acc 0.875000 val acc 0.814286
# epoch 136 tr loss 8.60 val loss 3.68 tr acc 0.853571 val acc 0.771429
# epoch 137 tr loss 9.57 val loss 3.81 tr acc 0.860714 val acc 0.742857
# epoch 138 tr loss 9.31 val loss 3.47 tr acc 0.885714 val acc 0.814286
# epoch 139 tr loss 7.97 val loss 3.92 tr acc 0.875000 val acc 0.785714
# epoch 140 tr loss 8.44 val loss 4.04 tr acc 0.839286 val acc 0.742857
# epoch 141 tr loss 9.10 val loss 4.04 tr acc 0.850000 val acc 0.771429
# epoch 142 tr loss 8.62 val loss 3.51 tr acc 0.878571 val acc 0.814286
# epoch 143 tr loss 7.79 val loss 4.16 tr acc 0.867857 val acc 0.771429
# epoch 144 tr loss 9.09 val loss 3.88 tr acc 0.864286 val acc 0.771429
# epoch 145 tr loss 8.88 val loss 4.12 tr acc 0.882143 val acc 0.800000
# epoch 146 tr loss 8.13 val loss 4.04 tr acc 0.896429 val acc 0.800000
# epoch 147 tr loss 7.74 val loss 4.03 tr acc 0.892857 val acc 0.785714
# epoch 148 tr loss 7.17 val loss 4.32 tr acc 0.907143 val acc 0.757143
# epoch 149 tr loss 7.70 val loss 4.30 tr acc 0.846429 val acc 0.728571
# epoch 150 tr loss 7.70 val loss 4.12 tr acc 0.882143 val acc 0.771429
# epoch 151 tr loss 8.16 val loss 4.25 tr acc 0.853571 val acc 0.757143
# epoch 152 tr loss 8.16 val loss 4.08 tr acc 0.892857 val acc 0.814286
# epoch 153 tr loss 10.61 val loss 4.64 tr acc 0.807143 val acc 0.728571
# epoch 154 tr loss 11.40 val loss 3.86 tr acc 0.867857 val acc 0.771429
# epoch 155 tr loss 8.35 val loss 3.62 tr acc 0.900000 val acc 0.814286
# epoch 156 tr loss 8.10 val loss 4.06 tr acc 0.867857 val acc 0.757143
# epoch 157 tr loss 8.27 val loss 4.39 tr acc 0.878571 val acc 0.771429
# epoch 158 tr loss 7.82 val loss 4.06 tr acc 0.892857 val acc 0.771429
# epoch 159 tr loss 7.25 val loss 4.49 tr acc 0.885714 val acc 0.728571
# epoch 160 tr loss 7.37 val loss 4.12 tr acc 0.885714 val acc 0.757143
# epoch 161 tr loss 6.96 val loss 3.95 tr acc 0.889286 val acc 0.757143
# epoch 162 tr loss 7.90 val loss 3.98 tr acc 0.875000 val acc 0.742857
# epoch 163 tr loss 8.24 val loss 3.94 tr acc 0.882143 val acc 0.742857
# epoch 164 tr loss 7.32 val loss 3.71 tr acc 0.896429 val acc 0.785714
# epoch 165 tr loss 7.27 val loss 3.77 tr acc 0.910714 val acc 0.800000
# epoch 166 tr loss 10.27 val loss 3.93 tr acc 0.835714 val acc 0.714286
# epoch 167 tr loss 8.33 val loss 3.95 tr acc 0.885714 val acc 0.771429
# epoch 168 tr loss 7.81 val loss 4.91 tr acc 0.850000 val acc 0.700000
# epoch 169 tr loss 9.24 val loss 4.36 tr acc 0.864286 val acc 0.714286
# epoch 170 tr loss 12.21 val loss 3.98 tr acc 0.814286 val acc 0.771429
# epoch 171 tr loss 10.40 val loss 3.58 tr acc 0.864286 val acc 0.814286
# epoch 172 tr loss 9.58 val loss 3.11 tr acc 0.878571 val acc 0.828571
# epoch 173 tr loss 7.68 val loss 3.74 tr acc 0.889286 val acc 0.814286
# epoch 174 tr loss 7.46 val loss 3.64 tr acc 0.900000 val acc 0.800000
# epoch 175 tr loss 6.99 val loss 4.00 tr acc 0.900000 val acc 0.771429
# epoch 176 tr loss 6.80 val loss 3.76 tr acc 0.900000 val acc 0.771429
# epoch 177 tr loss 6.84 val loss 4.60 tr acc 0.885714 val acc 0.757143
# epoch 178 tr loss 6.84 val loss 3.80 tr acc 0.903571 val acc 0.814286
# epoch 179 tr loss 7.13 val loss 3.99 tr acc 0.889286 val acc 0.814286
# epoch 180 tr loss 6.63 val loss 4.06 tr acc 0.914286 val acc 0.814286
# epoch 181 tr loss 6.34 val loss 4.10 tr acc 0.914286 val acc 0.800000
# epoch 182 tr loss 6.09 val loss 4.19 tr acc 0.907143 val acc 0.800000
# epoch 183 tr loss 6.05 val loss 4.18 tr acc 0.928571 val acc 0.814286
# epoch 184 tr loss 6.11 val loss 4.10 tr acc 0.910714 val acc 0.800000
# epoch 185 tr loss 5.81 val loss 4.32 tr acc 0.928571 val acc 0.828571
# epoch 186 tr loss 6.01 val loss 4.14 tr acc 0.914286 val acc 0.800000
# epoch 187 tr loss 5.96 val loss 4.27 tr acc 0.935714 val acc 0.800000
# epoch 188 tr loss 6.07 val loss 4.57 tr acc 0.914286 val acc 0.785714
# epoch 189 tr loss 6.38 val loss 3.59 tr acc 0.896429 val acc 0.814286
# epoch 190 tr loss 6.89 val loss 3.81 tr acc 0.917857 val acc 0.771429
# epoch 191 tr loss 5.71 val loss 3.72 tr acc 0.910714 val acc 0.814286
# epoch 192 tr loss 5.72 val loss 3.62 tr acc 0.917857 val acc 0.800000
# epoch 193 tr loss 5.66 val loss 3.62 tr acc 0.917857 val acc 0.814286
# epoch 194 tr loss 5.58 val loss 3.73 tr acc 0.921429 val acc 0.814286
# epoch 195 tr loss 5.45 val loss 3.68 tr acc 0.917857 val acc 0.814286
# epoch 196 tr loss 5.41 val loss 3.80 tr acc 0.921429 val acc 0.814286
# epoch 197 tr loss 5.32 val loss 4.06 tr acc 0.928571 val acc 0.814286
# epoch 198 tr loss 5.34 val loss 4.35 tr acc 0.925000 val acc 0.828571
# epoch 199 tr loss 10.53 val loss 4.82 tr acc 0.717857 val acc 0.671429
# tr acc 86.43% val acc 85.71% at epoch 132
# epoch 0 tr loss 19.51 val loss 4.86 tr acc 0.492857 val acc 0.500000
# epoch 1 tr loss 19.43 val loss 4.85 tr acc 0.492857 val acc 0.500000
# epoch 2 tr loss 19.40 val loss 4.85 tr acc 0.560714 val acc 0.542857
# epoch 3 tr loss 19.37 val loss 4.84 tr acc 0.567857 val acc 0.585714
# epoch 4 tr loss 19.34 val loss 4.84 tr acc 0.560714 val acc 0.571429
# epoch 5 tr loss 19.31 val loss 4.83 tr acc 0.560714 val acc 0.571429
# epoch 6 tr loss 19.27 val loss 4.83 tr acc 0.571429 val acc 0.571429
# epoch 7 tr loss 19.21 val loss 4.82 tr acc 0.589286 val acc 0.585714
# epoch 8 tr loss 19.13 val loss 4.80 tr acc 0.585714 val acc 0.614286
# epoch 9 tr loss 19.03 val loss 4.78 tr acc 0.603571 val acc 0.600000
# epoch 10 tr loss 18.95 val loss 4.78 tr acc 0.610714 val acc 0.614286
# epoch 11 tr loss 18.86 val loss 4.78 tr acc 0.632143 val acc 0.585714
# epoch 12 tr loss 18.79 val loss 4.78 tr acc 0.650000 val acc 0.614286
# epoch 13 tr loss 18.71 val loss 4.77 tr acc 0.646429 val acc 0.628571
# epoch 14 tr loss 18.63 val loss 4.75 tr acc 0.675000 val acc 0.642857
# epoch 15 tr loss 18.53 val loss 4.73 tr acc 0.675000 val acc 0.657143
# epoch 16 tr loss 18.41 val loss 4.70 tr acc 0.657143 val acc 0.657143
# epoch 17 tr loss 18.27 val loss 4.67 tr acc 0.671429 val acc 0.671429
# epoch 18 tr loss 18.13 val loss 4.63 tr acc 0.660714 val acc 0.685714
# epoch 19 tr loss 18.00 val loss 4.57 tr acc 0.682143 val acc 0.700000
# epoch 20 tr loss 17.98 val loss 4.55 tr acc 0.707143 val acc 0.685714
# epoch 21 tr loss 17.84 val loss 4.48 tr acc 0.707143 val acc 0.728571
# epoch 22 tr loss 17.66 val loss 4.42 tr acc 0.725000 val acc 0.714286
# epoch 23 tr loss 17.57 val loss 4.42 tr acc 0.710714 val acc 0.714286
# epoch 24 tr loss 17.42 val loss 4.35 tr acc 0.732143 val acc 0.757143
# epoch 25 tr loss 17.42 val loss 4.39 tr acc 0.721429 val acc 0.685714
# epoch 26 tr loss 16.96 val loss 4.29 tr acc 0.703571 val acc 0.728571
# epoch 27 tr loss 17.21 val loss 4.32 tr acc 0.725000 val acc 0.728571
# epoch 28 tr loss 16.64 val loss 4.26 tr acc 0.692857 val acc 0.728571
# epoch 29 tr loss 16.55 val loss 4.28 tr acc 0.685714 val acc 0.700000
# epoch 30 tr loss 16.71 val loss 4.15 tr acc 0.750000 val acc 0.757143
# epoch 31 tr loss 16.35 val loss 4.05 tr acc 0.764286 val acc 0.771429
# epoch 32 tr loss 15.86 val loss 4.04 tr acc 0.710714 val acc 0.700000
# epoch 33 tr loss 15.94 val loss 4.10 tr acc 0.717857 val acc 0.757143
# epoch 34 tr loss 15.14 val loss 4.56 tr acc 0.667857 val acc 0.671429
# epoch 35 tr loss 17.03 val loss 4.14 tr acc 0.771429 val acc 0.757143
# epoch 36 tr loss 15.65 val loss 3.99 tr acc 0.714286 val acc 0.742857
# epoch 37 tr loss 15.85 val loss 4.02 tr acc 0.725000 val acc 0.757143
# epoch 38 tr loss 15.12 val loss 3.61 tr acc 0.746429 val acc 0.771429
# epoch 39 tr loss 15.12 val loss 4.05 tr acc 0.714286 val acc 0.728571
# epoch 40 tr loss 14.88 val loss 3.76 tr acc 0.735714 val acc 0.785714
# epoch 41 tr loss 14.50 val loss 3.94 tr acc 0.714286 val acc 0.700000
# epoch 42 tr loss 14.93 val loss 3.45 tr acc 0.750000 val acc 0.800000
# epoch 43 tr loss 16.42 val loss 3.99 tr acc 0.767857 val acc 0.714286
# epoch 44 tr loss 15.12 val loss 3.60 tr acc 0.771429 val acc 0.800000
# epoch 45 tr loss 14.09 val loss 3.74 tr acc 0.732143 val acc 0.714286
# epoch 46 tr loss 14.21 val loss 3.51 tr acc 0.753571 val acc 0.742857
# epoch 47 tr loss 13.95 val loss 3.51 tr acc 0.757143 val acc 0.771429
# epoch 48 tr loss 13.86 val loss 3.59 tr acc 0.753571 val acc 0.757143
# epoch 49 tr loss 13.75 val loss 3.45 tr acc 0.760714 val acc 0.785714
# epoch 50 tr loss 13.59 val loss 3.37 tr acc 0.771429 val acc 0.785714
# epoch 51 tr loss 13.71 val loss 3.36 tr acc 0.771429 val acc 0.785714
# epoch 52 tr loss 13.43 val loss 3.22 tr acc 0.796429 val acc 0.800000
# epoch 53 tr loss 16.11 val loss 3.77 tr acc 0.775000 val acc 0.728571
# epoch 54 tr loss 14.23 val loss 3.19 tr acc 0.785714 val acc 0.814286
# epoch 55 tr loss 13.58 val loss 3.91 tr acc 0.764286 val acc 0.728571
# epoch 56 tr loss 14.03 val loss 4.18 tr acc 0.753571 val acc 0.771429
# epoch 57 tr loss 13.27 val loss 3.40 tr acc 0.757143 val acc 0.785714
# epoch 58 tr loss 13.42 val loss 3.28 tr acc 0.775000 val acc 0.814286
# epoch 59 tr loss 13.02 val loss 3.26 tr acc 0.785714 val acc 0.785714
# epoch 60 tr loss 13.33 val loss 3.59 tr acc 0.760714 val acc 0.800000
# epoch 61 tr loss 13.14 val loss 3.81 tr acc 0.742857 val acc 0.757143
# epoch 62 tr loss 13.21 val loss 3.18 tr acc 0.803571 val acc 0.828571
# epoch 63 tr loss 12.58 val loss 3.35 tr acc 0.742857 val acc 0.800000
# epoch 64 tr loss 12.79 val loss 3.42 tr acc 0.775000 val acc 0.814286
# epoch 65 tr loss 12.79 val loss 3.70 tr acc 0.782143 val acc 0.785714
# epoch 66 tr loss 12.65 val loss 3.86 tr acc 0.750000 val acc 0.785714
# epoch 67 tr loss 12.92 val loss 3.77 tr acc 0.800000 val acc 0.814286
# epoch 68 tr loss 12.75 val loss 3.84 tr acc 0.785714 val acc 0.771429
# epoch 69 tr loss 15.44 val loss 3.83 tr acc 0.735714 val acc 0.700000
# epoch 70 tr loss 14.91 val loss 3.61 tr acc 0.814286 val acc 0.800000
# epoch 71 tr loss 13.16 val loss 3.21 tr acc 0.803571 val acc 0.828571
# epoch 72 tr loss 13.72 val loss 3.57 tr acc 0.796429 val acc 0.742857
# epoch 73 tr loss 13.26 val loss 3.26 tr acc 0.810714 val acc 0.785714
# epoch 74 tr loss 12.58 val loss 3.37 tr acc 0.796429 val acc 0.785714
# epoch 75 tr loss 14.05 val loss 4.06 tr acc 0.771429 val acc 0.700000
# epoch 76 tr loss 13.23 val loss 3.21 tr acc 0.810714 val acc 0.828571
# epoch 77 tr loss 12.39 val loss 3.31 tr acc 0.810714 val acc 0.814286
# epoch 78 tr loss 13.37 val loss 3.32 tr acc 0.792857 val acc 0.742857
# epoch 79 tr loss 12.69 val loss 3.00 tr acc 0.817857 val acc 0.828571
# epoch 80 tr loss 12.45 val loss 3.52 tr acc 0.803571 val acc 0.828571
# epoch 81 tr loss 12.98 val loss 3.29 tr acc 0.807143 val acc 0.828571
# epoch 82 tr loss 12.69 val loss 3.21 tr acc 0.800000 val acc 0.842857
# epoch 83 tr loss 11.98 val loss 3.11 tr acc 0.814286 val acc 0.857143
# epoch 84 tr loss 11.99 val loss 3.16 tr acc 0.810714 val acc 0.814286
# epoch 85 tr loss 12.03 val loss 3.50 tr acc 0.828571 val acc 0.828571
# epoch 86 tr loss 12.64 val loss 3.44 tr acc 0.814286 val acc 0.814286
# epoch 87 tr loss 13.21 val loss 3.38 tr acc 0.775000 val acc 0.785714
# epoch 88 tr loss 12.61 val loss 3.06 tr acc 0.807143 val acc 0.842857
# epoch 89 tr loss 12.49 val loss 3.02 tr acc 0.803571 val acc 0.800000
# epoch 90 tr loss 11.75 val loss 2.83 tr acc 0.821429 val acc 0.814286
# epoch 91 tr loss 11.44 val loss 2.90 tr acc 0.807143 val acc 0.814286
# epoch 92 tr loss 11.52 val loss 3.06 tr acc 0.810714 val acc 0.828571
# epoch 93 tr loss 11.74 val loss 3.23 tr acc 0.807143 val acc 0.828571
# epoch 94 tr loss 11.31 val loss 3.09 tr acc 0.825000 val acc 0.842857
# epoch 95 tr loss 11.31 val loss 2.99 tr acc 0.828571 val acc 0.828571
# epoch 96 tr loss 11.24 val loss 3.00 tr acc 0.828571 val acc 0.842857
# epoch 97 tr loss 11.21 val loss 3.13 tr acc 0.821429 val acc 0.857143
# epoch 98 tr loss 11.11 val loss 3.17 tr acc 0.835714 val acc 0.828571
# epoch 99 tr loss 11.24 val loss 3.60 tr acc 0.817857 val acc 0.814286
# epoch 100 tr loss 14.52 val loss 4.00 tr acc 0.778571 val acc 0.671429
# epoch 101 tr loss 14.55 val loss 3.13 tr acc 0.828571 val acc 0.842857
# epoch 102 tr loss 12.18 val loss 2.85 tr acc 0.800000 val acc 0.871429
# epoch 103 tr loss 11.44 val loss 2.89 tr acc 0.814286 val acc 0.857143
# epoch 104 tr loss 11.33 val loss 2.80 tr acc 0.839286 val acc 0.842857
# epoch 105 tr loss 11.16 val loss 2.79 tr acc 0.825000 val acc 0.885714
# epoch 106 tr loss 11.05 val loss 2.79 tr acc 0.817857 val acc 0.900000
# epoch 107 tr loss 10.90 val loss 2.80 tr acc 0.825000 val acc 0.871429
# epoch 108 tr loss 10.81 val loss 2.82 tr acc 0.828571 val acc 0.885714
# epoch 109 tr loss 10.75 val loss 2.84 tr acc 0.850000 val acc 0.885714
# epoch 110 tr loss 10.70 val loss 2.86 tr acc 0.857143 val acc 0.900000
# epoch 111 tr loss 10.64 val loss 2.88 tr acc 0.853571 val acc 0.900000
# epoch 112 tr loss 10.60 val loss 2.91 tr acc 0.857143 val acc 0.885714
# epoch 113 tr loss 10.61 val loss 2.94 tr acc 0.853571 val acc 0.871429
# epoch 114 tr loss 10.52 val loss 3.02 tr acc 0.842857 val acc 0.857143
# epoch 115 tr loss 10.55 val loss 3.10 tr acc 0.842857 val acc 0.857143
# epoch 116 tr loss 10.56 val loss 3.19 tr acc 0.839286 val acc 0.871429
# epoch 117 tr loss 10.62 val loss 3.19 tr acc 0.839286 val acc 0.871429
# epoch 118 tr loss 10.58 val loss 3.15 tr acc 0.842857 val acc 0.857143
# epoch 119 tr loss 10.44 val loss 3.05 tr acc 0.846429 val acc 0.842857
# epoch 120 tr loss 10.21 val loss 2.95 tr acc 0.853571 val acc 0.885714
# epoch 121 tr loss 10.03 val loss 2.90 tr acc 0.860714 val acc 0.885714
# epoch 122 tr loss 9.86 val loss 2.92 tr acc 0.853571 val acc 0.871429
# epoch 123 tr loss 9.74 val loss 2.99 tr acc 0.853571 val acc 0.871429
# epoch 124 tr loss 9.93 val loss 3.14 tr acc 0.846429 val acc 0.885714
# epoch 125 tr loss 9.62 val loss 3.21 tr acc 0.853571 val acc 0.842857
# epoch 126 tr loss 10.79 val loss 3.15 tr acc 0.850000 val acc 0.828571
# epoch 127 tr loss 10.54 val loss 2.82 tr acc 0.825000 val acc 0.814286
# epoch 128 tr loss 10.26 val loss 3.06 tr acc 0.846429 val acc 0.857143
# epoch 129 tr loss 9.97 val loss 3.20 tr acc 0.850000 val acc 0.842857
# epoch 130 tr loss 10.12 val loss 3.08 tr acc 0.857143 val acc 0.871429
# epoch 131 tr loss 9.86 val loss 3.00 tr acc 0.864286 val acc 0.885714
# epoch 132 tr loss 9.49 val loss 3.12 tr acc 0.860714 val acc 0.857143
# epoch 133 tr loss 10.03 val loss 2.94 tr acc 0.867857 val acc 0.842857
# epoch 134 tr loss 9.90 val loss 2.86 tr acc 0.850000 val acc 0.871429
# epoch 135 tr loss 9.52 val loss 3.23 tr acc 0.885714 val acc 0.828571
# epoch 136 tr loss 9.61 val loss 3.10 tr acc 0.867857 val acc 0.828571
# epoch 137 tr loss 10.62 val loss 3.25 tr acc 0.842857 val acc 0.842857
# epoch 138 tr loss 9.97 val loss 3.42 tr acc 0.853571 val acc 0.828571
# epoch 139 tr loss 9.52 val loss 3.36 tr acc 0.860714 val acc 0.828571
# epoch 140 tr loss 9.22 val loss 3.50 tr acc 0.867857 val acc 0.828571
# epoch 141 tr loss 9.41 val loss 3.10 tr acc 0.885714 val acc 0.842857
# epoch 142 tr loss 9.17 val loss 3.16 tr acc 0.878571 val acc 0.814286
# epoch 143 tr loss 9.23 val loss 3.41 tr acc 0.878571 val acc 0.800000
# epoch 144 tr loss 9.07 val loss 3.15 tr acc 0.871429 val acc 0.814286
# epoch 145 tr loss 8.66 val loss 3.83 tr acc 0.867857 val acc 0.842857
# epoch 146 tr loss 9.26 val loss 3.72 tr acc 0.878571 val acc 0.785714
# epoch 147 tr loss 9.08 val loss 3.21 tr acc 0.875000 val acc 0.814286
# epoch 148 tr loss 12.56 val loss 4.38 tr acc 0.764286 val acc 0.785714
# epoch 149 tr loss 11.47 val loss 2.73 tr acc 0.821429 val acc 0.842857
# epoch 150 tr loss 10.40 val loss 2.92 tr acc 0.810714 val acc 0.857143
# epoch 151 tr loss 9.76 val loss 2.83 tr acc 0.832143 val acc 0.828571
# epoch 152 tr loss 9.79 val loss 2.79 tr acc 0.846429 val acc 0.857143
# epoch 153 tr loss 9.38 val loss 2.81 tr acc 0.878571 val acc 0.842857
# epoch 154 tr loss 9.02 val loss 2.90 tr acc 0.875000 val acc 0.871429
# epoch 155 tr loss 9.20 val loss 2.76 tr acc 0.875000 val acc 0.857143
# epoch 156 tr loss 8.76 val loss 2.85 tr acc 0.867857 val acc 0.842857
# epoch 157 tr loss 9.46 val loss 2.73 tr acc 0.878571 val acc 0.800000
# epoch 158 tr loss 9.03 val loss 2.64 tr acc 0.889286 val acc 0.857143
# epoch 159 tr loss 8.18 val loss 2.97 tr acc 0.896429 val acc 0.842857
# epoch 160 tr loss 8.23 val loss 2.96 tr acc 0.896429 val acc 0.842857
# epoch 161 tr loss 8.21 val loss 2.99 tr acc 0.889286 val acc 0.857143
# epoch 162 tr loss 7.93 val loss 3.11 tr acc 0.889286 val acc 0.842857
# epoch 163 tr loss 8.37 val loss 3.24 tr acc 0.892857 val acc 0.857143
# epoch 164 tr loss 7.98 val loss 3.05 tr acc 0.885714 val acc 0.857143
# epoch 165 tr loss 8.21 val loss 3.74 tr acc 0.889286 val acc 0.800000
# epoch 166 tr loss 10.26 val loss 3.31 tr acc 0.871429 val acc 0.771429
# epoch 167 tr loss 8.80 val loss 2.86 tr acc 0.889286 val acc 0.842857
# epoch 168 tr loss 7.66 val loss 3.61 tr acc 0.889286 val acc 0.842857
# epoch 169 tr loss 8.27 val loss 3.21 tr acc 0.878571 val acc 0.800000
# epoch 170 tr loss 10.23 val loss 2.97 tr acc 0.832143 val acc 0.785714
# epoch 171 tr loss 8.98 val loss 3.12 tr acc 0.896429 val acc 0.857143
# epoch 172 tr loss 8.22 val loss 3.26 tr acc 0.892857 val acc 0.857143
# epoch 173 tr loss 7.98 val loss 3.25 tr acc 0.896429 val acc 0.857143
# epoch 174 tr loss 7.59 val loss 3.53 tr acc 0.896429 val acc 0.814286
# epoch 175 tr loss 7.60 val loss 3.83 tr acc 0.889286 val acc 0.785714
# epoch 176 tr loss 7.39 val loss 3.87 tr acc 0.903571 val acc 0.800000
# epoch 177 tr loss 7.65 val loss 4.43 tr acc 0.871429 val acc 0.757143
# epoch 178 tr loss 7.70 val loss 3.67 tr acc 0.900000 val acc 0.800000
# epoch 179 tr loss 8.23 val loss 4.06 tr acc 0.907143 val acc 0.842857
# epoch 180 tr loss 7.30 val loss 3.55 tr acc 0.892857 val acc 0.828571
# epoch 181 tr loss 8.65 val loss 3.42 tr acc 0.885714 val acc 0.857143
# epoch 182 tr loss 10.19 val loss 3.60 tr acc 0.828571 val acc 0.785714
# epoch 183 tr loss 9.36 val loss 3.16 tr acc 0.853571 val acc 0.814286
# epoch 184 tr loss 8.98 val loss 2.94 tr acc 0.878571 val acc 0.828571
# epoch 185 tr loss 8.71 val loss 2.80 tr acc 0.875000 val acc 0.814286
# epoch 186 tr loss 8.32 val loss 2.96 tr acc 0.896429 val acc 0.814286
# epoch 187 tr loss 7.83 val loss 3.25 tr acc 0.896429 val acc 0.828571
# epoch 188 tr loss 7.15 val loss 3.58 tr acc 0.885714 val acc 0.814286
# epoch 189 tr loss 7.07 val loss 4.56 tr acc 0.900000 val acc 0.785714
# epoch 190 tr loss 6.77 val loss 4.73 tr acc 0.900000 val acc 0.785714
# epoch 191 tr loss 6.97 val loss 5.18 tr acc 0.900000 val acc 0.785714
# epoch 192 tr loss 7.13 val loss 3.96 tr acc 0.892857 val acc 0.828571
# epoch 193 tr loss 7.87 val loss 4.87 tr acc 0.903571 val acc 0.842857
# epoch 194 tr loss 7.07 val loss 4.17 tr acc 0.914286 val acc 0.785714
# epoch 195 tr loss 7.37 val loss 4.78 tr acc 0.903571 val acc 0.828571
# epoch 196 tr loss 6.61 val loss 4.37 tr acc 0.892857 val acc 0.828571
# epoch 197 tr loss 7.50 val loss 5.10 tr acc 0.892857 val acc 0.814286
# epoch 198 tr loss 6.87 val loss 4.26 tr acc 0.875000 val acc 0.771429
# epoch 199 tr loss 7.37 val loss 5.12 tr acc 0.885714 val acc 0.800000
# tr acc 81.79% val acc 90.00% at epoch 106
# epoch 0 tr loss 19.64 val loss 5.03 tr acc 0.510714 val acc 0.428571
# epoch 1 tr loss 19.49 val loss 4.95 tr acc 0.510714 val acc 0.428571
# epoch 2 tr loss 19.42 val loss 4.90 tr acc 0.510714 val acc 0.428571
# epoch 3 tr loss 19.39 val loss 4.88 tr acc 0.517857 val acc 0.457143
# epoch 4 tr loss 19.37 val loss 4.86 tr acc 0.521429 val acc 0.442857
# epoch 5 tr loss 19.36 val loss 4.85 tr acc 0.521429 val acc 0.514286
# epoch 6 tr loss 19.34 val loss 4.84 tr acc 0.517857 val acc 0.514286
# epoch 7 tr loss 19.33 val loss 4.84 tr acc 0.521429 val acc 0.528571
# epoch 8 tr loss 19.31 val loss 4.83 tr acc 0.525000 val acc 0.542857
# epoch 9 tr loss 19.30 val loss 4.83 tr acc 0.535714 val acc 0.542857
# epoch 10 tr loss 19.28 val loss 4.82 tr acc 0.535714 val acc 0.557143
# epoch 11 tr loss 19.26 val loss 4.81 tr acc 0.539286 val acc 0.571429
# epoch 12 tr loss 19.24 val loss 4.80 tr acc 0.542857 val acc 0.600000
# epoch 13 tr loss 19.21 val loss 4.78 tr acc 0.553571 val acc 0.585714
# epoch 14 tr loss 19.18 val loss 4.76 tr acc 0.585714 val acc 0.542857
# epoch 15 tr loss 19.13 val loss 4.73 tr acc 0.600000 val acc 0.557143
# epoch 16 tr loss 19.09 val loss 4.70 tr acc 0.628571 val acc 0.557143
# epoch 17 tr loss 19.00 val loss 4.67 tr acc 0.653571 val acc 0.600000
# epoch 18 tr loss 18.91 val loss 4.63 tr acc 0.657143 val acc 0.642857
# epoch 19 tr loss 18.83 val loss 4.63 tr acc 0.653571 val acc 0.642857
# epoch 20 tr loss 18.83 val loss 4.63 tr acc 0.675000 val acc 0.628571
# epoch 21 tr loss 18.44 val loss 4.61 tr acc 0.621429 val acc 0.585714
# epoch 22 tr loss 18.29 val loss 4.62 tr acc 0.607143 val acc 0.585714
# epoch 23 tr loss 18.37 val loss 4.61 tr acc 0.639286 val acc 0.628571
# epoch 24 tr loss 18.22 val loss 4.58 tr acc 0.628571 val acc 0.628571
# epoch 25 tr loss 18.29 val loss 4.65 tr acc 0.692857 val acc 0.628571
# epoch 26 tr loss 17.80 val loss 4.59 tr acc 0.646429 val acc 0.600000
# epoch 27 tr loss 17.79 val loss 4.53 tr acc 0.667857 val acc 0.628571
# epoch 28 tr loss 17.52 val loss 4.51 tr acc 0.646429 val acc 0.628571
# epoch 29 tr loss 17.33 val loss 4.49 tr acc 0.657143 val acc 0.628571
# epoch 30 tr loss 17.09 val loss 4.49 tr acc 0.671429 val acc 0.642857
# epoch 31 tr loss 16.89 val loss 4.47 tr acc 0.710714 val acc 0.671429
# epoch 32 tr loss 17.22 val loss 4.60 tr acc 0.717857 val acc 0.642857
# epoch 33 tr loss 16.60 val loss 4.41 tr acc 0.685714 val acc 0.685714
# epoch 34 tr loss 16.43 val loss 4.28 tr acc 0.700000 val acc 0.714286
# epoch 35 tr loss 16.08 val loss 4.32 tr acc 0.725000 val acc 0.671429
# epoch 36 tr loss 16.54 val loss 4.39 tr acc 0.735714 val acc 0.642857
# epoch 37 tr loss 15.92 val loss 4.20 tr acc 0.692857 val acc 0.685714
# epoch 38 tr loss 15.80 val loss 4.18 tr acc 0.764286 val acc 0.728571
# epoch 39 tr loss 15.68 val loss 4.15 tr acc 0.671429 val acc 0.700000
# epoch 40 tr loss 15.50 val loss 4.07 tr acc 0.742857 val acc 0.685714
# epoch 41 tr loss 16.03 val loss 4.11 tr acc 0.767857 val acc 0.700000
# epoch 42 tr loss 15.58 val loss 4.11 tr acc 0.739286 val acc 0.685714
# epoch 43 tr loss 15.41 val loss 4.20 tr acc 0.771429 val acc 0.714286
# epoch 44 tr loss 15.72 val loss 4.04 tr acc 0.782143 val acc 0.714286
# epoch 45 tr loss 14.79 val loss 4.08 tr acc 0.775000 val acc 0.700000
# epoch 46 tr loss 15.08 val loss 3.98 tr acc 0.750000 val acc 0.700000
# epoch 47 tr loss 15.22 val loss 3.99 tr acc 0.764286 val acc 0.685714
# epoch 48 tr loss 14.36 val loss 3.90 tr acc 0.778571 val acc 0.685714
# epoch 49 tr loss 15.04 val loss 4.16 tr acc 0.753571 val acc 0.700000
# epoch 50 tr loss 14.48 val loss 4.56 tr acc 0.757143 val acc 0.671429
# epoch 51 tr loss 15.36 val loss 3.75 tr acc 0.782143 val acc 0.771429
# epoch 52 tr loss 13.61 val loss 3.97 tr acc 0.792857 val acc 0.742857
# epoch 53 tr loss 15.31 val loss 4.43 tr acc 0.667857 val acc 0.600000
# epoch 54 tr loss 15.55 val loss 3.71 tr acc 0.746429 val acc 0.728571
# epoch 55 tr loss 14.08 val loss 3.85 tr acc 0.792857 val acc 0.728571
# epoch 56 tr loss 13.45 val loss 4.03 tr acc 0.750000 val acc 0.700000
# epoch 57 tr loss 13.48 val loss 4.36 tr acc 0.789286 val acc 0.742857
# epoch 58 tr loss 14.03 val loss 3.68 tr acc 0.807143 val acc 0.742857
# epoch 59 tr loss 14.00 val loss 3.82 tr acc 0.782143 val acc 0.671429
# epoch 60 tr loss 13.46 val loss 3.92 tr acc 0.792857 val acc 0.685714
# epoch 61 tr loss 13.26 val loss 3.87 tr acc 0.764286 val acc 0.757143
# epoch 62 tr loss 13.05 val loss 3.94 tr acc 0.796429 val acc 0.700000
# epoch 63 tr loss 12.83 val loss 4.44 tr acc 0.789286 val acc 0.671429
# epoch 64 tr loss 14.75 val loss 3.58 tr acc 0.764286 val acc 0.785714
# epoch 65 tr loss 13.44 val loss 4.22 tr acc 0.757143 val acc 0.728571
# epoch 66 tr loss 15.52 val loss 4.20 tr acc 0.732143 val acc 0.714286
# epoch 67 tr loss 16.48 val loss 4.48 tr acc 0.678571 val acc 0.714286
# epoch 68 tr loss 14.56 val loss 3.88 tr acc 0.725000 val acc 0.671429
# epoch 69 tr loss 14.81 val loss 3.69 tr acc 0.785714 val acc 0.785714
# epoch 70 tr loss 14.02 val loss 3.55 tr acc 0.732143 val acc 0.757143
# epoch 71 tr loss 13.55 val loss 3.89 tr acc 0.764286 val acc 0.757143
# epoch 72 tr loss 15.99 val loss 4.15 tr acc 0.660714 val acc 0.671429
# epoch 73 tr loss 16.08 val loss 3.76 tr acc 0.760714 val acc 0.714286
# epoch 74 tr loss 13.75 val loss 3.56 tr acc 0.767857 val acc 0.757143
# epoch 75 tr loss 13.84 val loss 3.60 tr acc 0.671429 val acc 0.728571
# epoch 76 tr loss 14.85 val loss 3.71 tr acc 0.714286 val acc 0.742857
# epoch 77 tr loss 13.64 val loss 3.98 tr acc 0.782143 val acc 0.757143
# epoch 78 tr loss 14.50 val loss 3.61 tr acc 0.775000 val acc 0.757143
# epoch 79 tr loss 13.94 val loss 3.88 tr acc 0.792857 val acc 0.714286
# epoch 80 tr loss 13.20 val loss 3.76 tr acc 0.782143 val acc 0.728571
# epoch 81 tr loss 12.96 val loss 3.71 tr acc 0.778571 val acc 0.757143
# epoch 82 tr loss 12.75 val loss 3.76 tr acc 0.803571 val acc 0.742857
# ...
# epoch 118 tr loss 9.70 val loss 3.21 tr acc 0.867857 val acc 0.800000
# epoch 119 tr loss 9.43 val loss 3.23 tr acc 0.860714 val acc 0.800000
# epoch 120 tr loss 11.59 val loss 3.63 tr acc 0.764286 val acc 0.742857
# epoch 121 tr loss 12.83 val loss 3.26 tr acc 0.860714 val acc 0.771429
# epoch 122 tr loss 9.82 val loss 3.23 tr acc 0.875000 val acc 0.785714
# epoch 123 tr loss 9.54 val loss 2.91 tr acc 0.875000 val acc 0.828571
# epoch 124 tr loss 9.64 val loss 2.82 tr acc 0.875000 val acc 0.814286
# epoch 125 tr loss 9.14 val loss 2.88 tr acc 0.878571 val acc 0.814286
# epoch 126 tr loss 8.96 val loss 3.02 tr acc 0.871429 val acc 0.771429
# epoch 127 tr loss 9.03 val loss 3.00 tr acc 0.885714 val acc 0.828571
# epoch 128 tr loss 8.84 val loss 3.28 tr acc 0.871429 val acc 0.757143
# epoch 129 tr loss 9.17 val loss 3.22 tr acc 0.853571 val acc 0.771429
# epoch 130 tr loss 9.86 val loss 3.26 tr acc 0.864286 val acc 0.728571
# epoch 131 tr loss 9.69 val loss 3.16 tr acc 0.864286 val acc 0.800000
# epoch 132 tr loss 8.92 val loss 2.99 tr acc 0.846429 val acc 0.800000
# epoch 133 tr loss 9.15 val loss 2.99 tr acc 0.875000 val acc 0.828571
# epoch 134 tr loss 8.38 val loss 2.94 tr acc 0.871429 val acc 0.800000
# epoch 135 tr loss 8.49 val loss 3.07 tr acc 0.878571 val acc 0.800000
# epoch 136 tr loss 8.59 val loss 3.12 tr acc 0.853571 val acc 0.742857
# epoch 137 tr loss 9.45 val loss 3.08 tr acc 0.889286 val acc 0.828571
# epoch 138 tr loss 8.89 val loss 3.17 tr acc 0.846429 val acc 0.771429
# epoch 139 tr loss 9.30 val loss 4.28 tr acc 0.846429 val acc 0.714286
# epoch 140 tr loss 9.26 val loss 3.17 tr acc 0.882143 val acc 0.814286
# epoch 141 tr loss 8.83 val loss 3.50 tr acc 0.896429 val acc 0.714286
# epoch 142 tr loss 8.29 val loss 2.99 tr acc 0.871429 val acc 0.828571
# epoch 143 tr loss 8.44 val loss 3.02 tr acc 0.850000 val acc 0.757143
# epoch 144 tr loss 9.05 val loss 2.80 tr acc 0.871429 val acc 0.814286
# epoch 145 tr loss 8.38 val loss 2.93 tr acc 0.857143 val acc 0.785714
# epoch 146 tr loss 8.92 val loss 3.03 tr acc 0.842857 val acc 0.771429
# epoch 147 tr loss 8.73 val loss 3.23 tr acc 0.867857 val acc 0.714286
# epoch 148 tr loss 8.70 val loss 4.20 tr acc 0.875000 val acc 0.728571
# epoch 149 tr loss 9.10 val loss 3.23 tr acc 0.896429 val acc 0.728571
# epoch 150 tr loss 8.21 val loss 2.85 tr acc 0.882143 val acc 0.785714
# epoch 151 tr loss 8.06 val loss 2.82 tr acc 0.878571 val acc 0.828571
# epoch 152 tr loss 8.12 val loss 2.81 tr acc 0.892857 val acc 0.814286
# epoch 153 tr loss 7.67 val loss 3.21 tr acc 0.885714 val acc 0.785714
# epoch 154 tr loss 8.44 val loss 2.90 tr acc 0.889286 val acc 0.828571
# epoch 155 tr loss 8.44 val loss 3.20 tr acc 0.871429 val acc 0.757143
# epoch 156 tr loss 8.48 val loss 2.77 tr acc 0.892857 val acc 0.842857
# epoch 157 tr loss 8.42 val loss 3.19 tr acc 0.842857 val acc 0.828571
# epoch 158 tr loss 10.08 val loss 2.62 tr acc 0.871429 val acc 0.857143
# epoch 159 tr loss 9.41 val loss 2.82 tr acc 0.860714 val acc 0.771429
# epoch 160 tr loss 8.05 val loss 2.49 tr acc 0.896429 val acc 0.842857
# epoch 161 tr loss 8.21 val loss 2.70 tr acc 0.900000 val acc 0.828571
# epoch 162 tr loss 8.16 val loss 2.46 tr acc 0.903571 val acc 0.871429
# epoch 163 tr loss 7.75 val loss 2.45 tr acc 0.910714 val acc 0.857143
# epoch 164 tr loss 7.52 val loss 2.49 tr acc 0.896429 val acc 0.857143
# epoch 165 tr loss 7.91 val loss 2.62 tr acc 0.907143 val acc 0.842857
# epoch 166 tr loss 8.11 val loss 2.57 tr acc 0.900000 val acc 0.842857
# epoch 167 tr loss 8.11 val loss 2.41 tr acc 0.900000 val acc 0.828571
# epoch 168 tr loss 7.31 val loss 2.35 tr acc 0.910714 val acc 0.857143
# epoch 169 tr loss 7.34 val loss 2.31 tr acc 0.914286 val acc 0.842857
# epoch 170 tr loss 7.13 val loss 2.92 tr acc 0.907143 val acc 0.800000
# epoch 171 tr loss 6.79 val loss 2.98 tr acc 0.910714 val acc 0.785714
# epoch 172 tr loss 6.73 val loss 3.20 tr acc 0.903571 val acc 0.800000
# epoch 173 tr loss 6.68 val loss 3.18 tr acc 0.903571 val acc 0.800000
# epoch 174 tr loss 6.53 val loss 3.14 tr acc 0.910714 val acc 0.800000
# epoch 175 tr loss 6.44 val loss 3.11 tr acc 0.914286 val acc 0.800000
# epoch 176 tr loss 6.41 val loss 3.12 tr acc 0.910714 val acc 0.800000
# epoch 177 tr loss 6.31 val loss 3.14 tr acc 0.907143 val acc 0.800000
# epoch 178 tr loss 6.24 val loss 3.10 tr acc 0.903571 val acc 0.800000
# epoch 179 tr loss 6.15 val loss 3.19 tr acc 0.907143 val acc 0.785714
# epoch 180 tr loss 6.06 val loss 3.16 tr acc 0.903571 val acc 0.785714
# epoch 181 tr loss 5.96 val loss 3.02 tr acc 0.921429 val acc 0.800000
# epoch 182 tr loss 5.79 val loss 3.15 tr acc 0.914286 val acc 0.800000
# epoch 183 tr loss 5.82 val loss 3.13 tr acc 0.907143 val acc 0.800000
# epoch 184 tr loss 5.64 val loss 3.15 tr acc 0.914286 val acc 0.800000
# epoch 185 tr loss 5.80 val loss 2.92 tr acc 0.896429 val acc 0.814286
# epoch 186 tr loss 5.64 val loss 3.17 tr acc 0.910714 val acc 0.785714
# epoch 187 tr loss 5.57 val loss 3.26 tr acc 0.903571 val acc 0.785714
# epoch 188 tr loss 5.62 val loss 3.66 tr acc 0.892857 val acc 0.742857
# epoch 189 tr loss 5.98 val loss 3.10 tr acc 0.900000 val acc 0.842857
# epoch 190 tr loss 6.13 val loss 3.20 tr acc 0.885714 val acc 0.785714
# epoch 191 tr loss 7.12 val loss 3.89 tr acc 0.878571 val acc 0.757143
# epoch 192 tr loss 8.56 val loss 2.82 tr acc 0.885714 val acc 0.828571
# epoch 193 tr loss 11.03 val loss 2.89 tr acc 0.903571 val acc 0.785714
# epoch 194 tr loss 8.36 val loss 2.50 tr acc 0.896429 val acc 0.828571
# epoch 195 tr loss 7.89 val loss 2.72 tr acc 0.910714 val acc 0.814286
# epoch 196 tr loss 7.08 val loss 2.21 tr acc 0.900000 val acc 0.842857
# epoch 197 tr loss 6.90 val loss 2.22 tr acc 0.914286 val acc 0.900000
# epoch 198 tr loss 7.47 val loss 2.69 tr acc 0.907143 val acc 0.800000
# epoch 199 tr loss 7.20 val loss 2.63 tr acc 0.896429 val acc 0.800000
# tr acc 91.43% val acc 90.00% at epoch 197
# epoch 0 tr loss 24.27 val loss 6.95 tr acc 0.508571 val acc 0.450000
# epoch 1 tr loss 24.24 val loss 6.96 tr acc 0.531429 val acc 0.470000
# epoch 2 tr loss 24.22 val loss 6.97 tr acc 0.548571 val acc 0.470000
# epoch 3 tr loss 24.20 val loss 6.98 tr acc 0.554286 val acc 0.470000
# epoch 4 tr loss 24.17 val loss 7.00 tr acc 0.562857 val acc 0.480000
# epoch 5 tr loss 24.14 val loss 7.02 tr acc 0.562857 val acc 0.480000
# epoch 6 tr loss 24.10 val loss 7.06 tr acc 0.551429 val acc 0.470000
# epoch 7 tr loss 24.06 val loss 7.13 tr acc 0.548571 val acc 0.480000
# epoch 8 tr loss 24.00 val loss 7.22 tr acc 0.560000 val acc 0.500000
# epoch 9 tr loss 23.94 val loss 7.30 tr acc 0.588571 val acc 0.490000
# epoch 10 tr loss 23.85 val loss 7.39 tr acc 0.591429 val acc 0.480000
# epoch 11 tr loss 23.72 val loss 7.46 tr acc 0.634286 val acc 0.540000
# epoch 12 tr loss 23.53 val loss 7.38 tr acc 0.685714 val acc 0.520000
# epoch 13 tr loss 23.22 val loss 7.22 tr acc 0.657143 val acc 0.530000
# epoch 14 tr loss 23.02 val loss 7.20 tr acc 0.637143 val acc 0.540000
# epoch 15 tr loss 22.63 val loss 7.45 tr acc 0.642857 val acc 0.550000
# epoch 16 tr loss 22.45 val loss 6.94 tr acc 0.660000 val acc 0.550000
# epoch 17 tr loss 22.20 val loss 6.82 tr acc 0.657143 val acc 0.560000
# epoch 18 tr loss 22.27 val loss 7.54 tr acc 0.634286 val acc 0.570000
# epoch 19 tr loss 22.10 val loss 6.96 tr acc 0.711429 val acc 0.600000
# epoch 20 tr loss 21.23 val loss 7.53 tr acc 0.677143 val acc 0.580000
# epoch 21 tr loss 21.28 val loss 6.69 tr acc 0.720000 val acc 0.600000
# epoch 22 tr loss 20.54 val loss 7.49 tr acc 0.648571 val acc 0.650000
# epoch 23 tr loss 21.25 val loss 6.86 tr acc 0.677143 val acc 0.630000
# epoch 24 tr loss 19.88 val loss 7.24 tr acc 0.677143 val acc 0.650000
# epoch 25 tr loss 19.22 val loss 7.01 tr acc 0.657143 val acc 0.670000
# epoch 26 tr loss 19.91 val loss 5.66 tr acc 0.748571 val acc 0.730000
# epoch 27 tr loss 19.20 val loss 6.11 tr acc 0.762857 val acc 0.680000
# epoch 28 tr loss 17.99 val loss 5.82 tr acc 0.745714 val acc 0.740000
# epoch 29 tr loss 18.65 val loss 5.64 tr acc 0.722857 val acc 0.710000
# epoch 30 tr loss 18.00 val loss 5.57 tr acc 0.780000 val acc 0.750000
# epoch 31 tr loss 18.10 val loss 5.92 tr acc 0.762857 val acc 0.700000
# epoch 32 tr loss 17.58 val loss 5.81 tr acc 0.785714 val acc 0.750000
# epoch 33 tr loss 17.05 val loss 5.36 tr acc 0.760000 val acc 0.710000
# epoch 34 tr loss 17.15 val loss 5.37 tr acc 0.734286 val acc 0.760000
# epoch 35 tr loss 16.41 val loss 5.67 tr acc 0.777143 val acc 0.750000
# epoch 36 tr loss 16.77 val loss 5.35 tr acc 0.762857 val acc 0.740000
# epoch 37 tr loss 16.12 val loss 5.36 tr acc 0.777143 val acc 0.770000
# epoch 38 tr loss 15.70 val loss 5.73 tr acc 0.794286 val acc 0.780000
# epoch 39 tr loss 15.98 val loss 5.63 tr acc 0.791429 val acc 0.780000
# epoch 40 tr loss 15.66 val loss 6.28 tr acc 0.800000 val acc 0.740000
# epoch 41 tr loss 15.05 val loss 7.17 tr acc 0.817143 val acc 0.740000
# epoch 42 tr loss 15.60 val loss 8.27 tr acc 0.777143 val acc 0.680000
# epoch 43 tr loss 15.09 val loss 6.57 tr acc 0.800000 val acc 0.740000
# epoch 44 tr loss 15.09 val loss 6.69 tr acc 0.817143 val acc 0.730000
# epoch 45 tr loss 14.71 val loss 7.38 tr acc 0.822857 val acc 0.750000
# epoch 46 tr loss 14.36 val loss 7.64 tr acc 0.828571 val acc 0.720000
# epoch 47 tr loss 14.29 val loss 7.17 tr acc 0.831429 val acc 0.720000
# epoch 48 tr loss 13.85 val loss 7.41 tr acc 0.828571 val acc 0.680000
# epoch 49 tr loss 13.52 val loss 7.62 tr acc 0.822857 val acc 0.710000
# epoch 50 tr loss 13.65 val loss 8.44 tr acc 0.837143 val acc 0.730000
# epoch 51 tr loss 14.40 val loss 7.78 tr acc 0.851429 val acc 0.760000
# epoch 52 tr loss 14.04 val loss 7.69 tr acc 0.831429 val acc 0.730000
# epoch 53 tr loss 13.19 val loss 7.46 tr acc 0.817143 val acc 0.700000
# epoch 54 tr loss 13.21 val loss 7.54 tr acc 0.840000 val acc 0.760000
# epoch 55 tr loss 14.31 val loss 7.52 tr acc 0.822857 val acc 0.650000
# epoch 56 tr loss 13.91 val loss 8.37 tr acc 0.825714 val acc 0.690000
# epoch 57 tr loss 13.21 val loss 8.36 tr acc 0.845714 val acc 0.740000
# epoch 58 tr loss 13.23 val loss 8.04 tr acc 0.851429 val acc 0.690000
# epoch 59 tr loss 12.48 val loss 8.01 tr acc 0.845714 val acc 0.680000
# epoch 60 tr loss 12.52 val loss 8.09 tr acc 0.857143 val acc 0.720000
# epoch 61 tr loss 12.91 val loss 8.39 tr acc 0.865714 val acc 0.660000
# epoch 62 tr loss 12.47 val loss 8.13 tr acc 0.845714 val acc 0.710000
# epoch 63 tr loss 12.17 val loss 8.54 tr acc 0.854286 val acc 0.660000
# epoch 64 tr loss 12.51 val loss 9.05 tr acc 0.860000 val acc 0.630000
# epoch 65 tr loss 12.33 val loss 8.65 tr acc 0.860000 val acc 0.680000
# epoch 66 tr loss 12.05 val loss 9.12 tr acc 0.862857 val acc 0.650000
# epoch 67 tr loss 12.08 val loss 9.35 tr acc 0.862857 val acc 0.640000
# epoch 68 tr loss 11.94 val loss 9.24 tr acc 0.865714 val acc 0.670000
# epoch 69 tr loss 11.93 val loss 9.89 tr acc 0.854286 val acc 0.650000
# epoch 70 tr loss 11.90 val loss 9.52 tr acc 0.865714 val acc 0.660000
# epoch 71 tr loss 11.79 val loss 10.01 tr acc 0.860000 val acc 0.660000
# epoch 72 tr loss 11.75 val loss 10.02 tr acc 0.865714 val acc 0.640000
# epoch 73 tr loss 11.66 val loss 10.03 tr acc 0.862857 val acc 0.650000
# epoch 74 tr loss 11.64 val loss 10.48 tr acc 0.857143 val acc 0.630000
# epoch 75 tr loss 11.58 val loss 9.98 tr acc 0.868571 val acc 0.670000
# epoch 76 tr loss 11.53 val loss 10.68 tr acc 0.848571 val acc 0.640000
# epoch 77 tr loss 11.47 val loss 9.94 tr acc 0.862857 val acc 0.680000
# epoch 78 tr loss 11.41 val loss 10.56 tr acc 0.854286 val acc 0.640000
# epoch 79 tr loss 11.38 val loss 10.22 tr acc 0.860000 val acc 0.670000
# epoch 80 tr loss 11.26 val loss 10.66 tr acc 0.857143 val acc 0.640000
# epoch 81 tr loss 11.30 val loss 11.02 tr acc 0.834286 val acc 0.640000
# epoch 82 tr loss 11.28 val loss 10.34 tr acc 0.862857 val acc 0.660000
# epoch 83 tr loss 11.20 val loss 11.30 tr acc 0.828571 val acc 0.630000
# epoch 84 tr loss 11.23 val loss 10.31 tr acc 0.874286 val acc 0.700000
# epoch 85 tr loss 11.29 val loss 11.60 tr acc 0.860000 val acc 0.640000
# epoch 86 tr loss 12.42 val loss 11.05 tr acc 0.794286 val acc 0.660000
# epoch 87 tr loss 13.14 val loss 9.65 tr acc 0.854286 val acc 0.670000
# epoch 88 tr loss 11.76 val loss 10.24 tr acc 0.865714 val acc 0.670000
# epoch 89 tr loss 11.36 val loss 10.82 tr acc 0.851429 val acc 0.650000
# epoch 90 tr loss 10.94 val loss 10.70 tr acc 0.851429 val acc 0.610000
# epoch 91 tr loss 10.75 val loss 10.73 tr acc 0.854286 val acc 0.660000
# epoch 92 tr loss 10.85 val loss 10.56 tr acc 0.860000 val acc 0.650000
# epoch 93 tr loss 10.77 val loss 10.70 tr acc 0.862857 val acc 0.660000
# epoch 94 tr loss 10.69 val loss 10.93 tr acc 0.862857 val acc 0.670000
# epoch 95 tr loss 10.64 val loss 11.30 tr acc 0.865714 val acc 0.660000
# epoch 96 tr loss 10.67 val loss 11.73 tr acc 0.868571 val acc 0.640000
# epoch 97 tr loss 10.83 val loss 12.20 tr acc 0.860000 val acc 0.650000
# epoch 98 tr loss 11.10 val loss 12.94 tr acc 0.854286 val acc 0.630000
# epoch 99 tr loss 12.06 val loss 16.39 tr acc 0.831429 val acc 0.570000
# epoch 100 tr loss 11.16 val loss 12.52 tr acc 0.857143 val acc 0.630000
# epoch 101 tr loss 10.93 val loss 12.29 tr acc 0.868571 val acc 0.640000
# epoch 102 tr loss 10.70 val loss 12.37 tr acc 0.871429 val acc 0.660000
# epoch 103 tr loss 10.29 val loss 12.17 tr acc 0.871429 val acc 0.670000
# epoch 104 tr loss 10.25 val loss 12.26 tr acc 0.871429 val acc 0.680000
# epoch 105 tr loss 10.20 val loss 12.44 tr acc 0.868571 val acc 0.680000
# epoch 106 tr loss 10.17 val loss 12.48 tr acc 0.868571 val acc 0.680000
# epoch 107 tr loss 10.15 val loss 12.49 tr acc 0.874286 val acc 0.660000
# epoch 108 tr loss 10.22 val loss 12.97 tr acc 0.868571 val acc 0.650000
# epoch 109 tr loss 10.42 val loss 13.73 tr acc 0.857143 val acc 0.620000
# epoch 110 tr loss 10.64 val loss 13.98 tr acc 0.840000 val acc 0.620000
# epoch 111 tr loss 10.53 val loss 13.18 tr acc 0.865714 val acc 0.640000
# epoch 112 tr loss 10.33 val loss 13.62 tr acc 0.865714 val acc 0.650000
# epoch 113 tr loss 11.04 val loss 13.26 tr acc 0.874286 val acc 0.640000
# epoch 114 tr loss 10.36 val loss 13.95 tr acc 0.877143 val acc 0.670000
# epoch 115 tr loss 10.51 val loss 13.98 tr acc 0.868571 val acc 0.660000
# epoch 116 tr loss 10.28 val loss 14.31 tr acc 0.871429 val acc 0.670000
# epoch 117 tr loss 10.14 val loss 14.55 tr acc 0.874286 val acc 0.680000
# epoch 118 tr loss 9.98 val loss 14.86 tr acc 0.877143 val acc 0.680000
# epoch 119 tr loss 9.79 val loss 15.08 tr acc 0.891429 val acc 0.680000
# epoch 120 tr loss 9.62 val loss 14.95 tr acc 0.888571 val acc 0.670000
# epoch 121 tr loss 9.54 val loss 14.33 tr acc 0.894286 val acc 0.680000
# epoch 122 tr loss 9.62 val loss 14.46 tr acc 0.865714 val acc 0.650000
# epoch 123 tr loss 9.68 val loss 14.69 tr acc 0.860000 val acc 0.630000
# epoch 124 tr loss 9.80 val loss 13.57 tr acc 0.874286 val acc 0.660000
# epoch 125 tr loss 9.92 val loss 14.93 tr acc 0.871429 val acc 0.660000
# epoch 126 tr loss 9.76 val loss 15.64 tr acc 0.880000 val acc 0.680000
# epoch 127 tr loss 9.43 val loss 15.28 tr acc 0.888571 val acc 0.680000
# epoch 128 tr loss 9.46 val loss 14.88 tr acc 0.888571 val acc 0.650000
# epoch 129 tr loss 9.41 val loss 15.28 tr acc 0.888571 val acc 0.650000
# epoch 130 tr loss 9.15 val loss 15.06 tr acc 0.888571 val acc 0.670000
# epoch 131 tr loss 9.31 val loss 16.17 tr acc 0.874286 val acc 0.660000
# epoch 132 tr loss 9.14 val loss 14.95 tr acc 0.891429 val acc 0.640000
# epoch 133 tr loss 9.05 val loss 16.01 tr acc 0.877143 val acc 0.630000
# epoch 134 tr loss 9.23 val loss 15.08 tr acc 0.880000 val acc 0.660000
# epoch 135 tr loss 9.35 val loss 16.86 tr acc 0.885714 val acc 0.660000
# epoch 136 tr loss 9.79 val loss 17.05 tr acc 0.888571 val acc 0.660000
# epoch 137 tr loss 9.45 val loss 17.59 tr acc 0.868571 val acc 0.650000
# epoch 138 tr loss 9.10 val loss 17.77 tr acc 0.902857 val acc 0.660000
# epoch 139 tr loss 9.36 val loss 17.54 tr acc 0.885714 val acc 0.660000
# epoch 140 tr loss 9.23 val loss 17.80 tr acc 0.885714 val acc 0.670000
# epoch 141 tr loss 9.16 val loss 16.99 tr acc 0.874286 val acc 0.660000
# epoch 142 tr loss 8.63 val loss 16.27 tr acc 0.900000 val acc 0.690000
# epoch 143 tr loss 9.01 val loss 16.63 tr acc 0.877143 val acc 0.650000
# accuracy = 0.65
