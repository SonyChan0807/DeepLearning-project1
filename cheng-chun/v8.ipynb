# %% [markdown]
# ### Libraries

# %%
import os
import random
import numpy as np
import matplotlib.pyplot as plt

import dlc_bci as bci
from dlc_practical_prologue import *

import torch
from torch import nn
from torch.nn import functional as F
from torch.autograd import Variable

import importlib
# customized libraries
import plot_lib as plib
import preprocess as prep

# %%
# tr_input[np.random.choice(tr_input.shape[0], 100, replace=False)].shape

# %%
importlib.reload(bci)
importlib.reload(plib)
importlib.reload(prep)
# Out:
# <module 'preprocess' from '/home/cheng-chun-epfl/Dropbox/EPFL/course/MA2/deep learning/min-project/cheng-chun/preprocess.py'>

# %% [markdown]
# ### Load dataset

# %%
# tr_input_org, tr_target_org = bci.load("bci", train=True, one_khz=True)
tr_input_org, tr_target_org = bci.load("bci", train=True, one_khz=False)
# te_input_org, te_target_org = bci.load("bci", train=False, one_khz=True)
te_input_org, te_target = bci.load("bci", train=False, one_khz=False)


tr_target_onehot = convert_to_one_hot_labels(tr_input_org, tr_target_org)
te_target_onehot = convert_to_one_hot_labels(te_input_org, te_target)

tr_target_onehot = Variable(tr_target_onehot)
te_target_onehot = Variable(te_target_onehot)

tr_target_org = Variable(tr_target_org)
te_target = Variable(te_target)

# %% [markdown]
# ### Preprocessing - moving average / downsampling / DC blocker / DFT

# %%
importlib.reload(prep)
# moving average
N = 7
# downsampling
Nd = 4
# DC blocker
alpha = 0.9
# find peak
Np = 6
# FFT extraction
size = 20


tr_input = tr_input_org.clone()
te_input = te_input_org.clone()
tr_target = tr_target_org.clone()



# inc_size = 700
tr_input, tr_target = prep.augment(tr_input, tr_target, 100)

# reserve_list = [0, 1, 4, 5, 7, 11, 15, 16, 19, 23, 26, 27]

# tr_input = prep.channel_used(tr_input, reserve_list)
# te_input = prep.channel_used(te_input, reserve_list)

# tr_input = channel_used(tr_input, reserve_list)

# tr_input = tr_input[:,:15,:]
# te_input = te_input[:,:15,:]

# peak detector
# tr_input = prep.peak_detector_filtering(tr_input, Np)
# te_input = prep.peak_detector_filtering(te_input, Np)

# low pass filtering
# tr_input = prep.lowpass_filtering(tr_input, N)
# te_input = prep.lowpass_filtering(te_input, N)

# downsampling
# tr_input = prep.downsampling_filtering(tr_input, Nd)
# te_input = prep.downsampling_filtering(te_input, Nd)


# dc block
# tr_input = dc_blocker_filtering(tr_input, alpha)
# te_input = dc_blocker_filtering(te_input, alpha)

# fft data generation
# tr_input = prep.fft_input_generation(tr_input, size, with_phase=False)
# te_input = prep.fft_input_generation(te_input, size, with_phase=False)
# tr_input = prep.fft_input_generation(tr_input, size, with_phase=True)
# te_input = prep.fft_input_generation(te_input, size, with_phase=True)

# spectrogram data generation
# tr_input = prep.spectrogram_input_generation(tr_input,freq=100,npers=5)
# te_input = prep.spectrogram_input_generation(te_input,freq=100,npers=5)

# %%
# plib.plot_pair(tr_input_org, tr_input)
# for i in range(28):
#     plib.plot_avg(tr_input, tr_target_onehot, i)

# %% [markdown]
# ### Standardize

# %%
num_channel = tr_input.shape[1]
signal_len = tr_input.shape[2]

tr_input = torch.nn.functional.normalize(tr_input, p=2, dim=0) 
te_input = torch.nn.functional.normalize(te_input, p=2, dim=0) 

# Convert to 4D tensor [dataset size, number of channels, rows, cols]
# tr_input = tr_input[:, np.newaxis, :, :]
# te_input = te_input[:, np.newaxis, :, :]

tr_input = Variable(tr_input)
te_input = Variable(te_input)

# tr_input = Variable(tr_input.view(-1,num_channel*signal_len))
# te_input = Variable(te_input.view(-1,num_channel*signal_len))

# %% [markdown]
# ### training

# %%
class Net(nn.Module):
    def __init__(self, num_channel, signal_len):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(num_channel * signal_len, signal_len)
        self.fc2 = nn.Linear(signal_len, signal_len)
        self.fc3 = nn.Linear(signal_len, 2)
        
    def forward(self, x, mode=False):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))        
        x = self.fc3(x)
        return x
    
class ConvNet(nn.Module):
    def __init__(self, ch, length, k_size):
        super(ConvNet, self).__init__()
        self.conv1 = nn.Conv1d(in_channels=ch, out_channels=ch, kernel_size=k_size)
        self.linear1 = nn.Linear((length-2)*ch//4, (length-2)*ch//4)
        self.output = nn.Linear((length-2)*ch//4, 2)
        self.length = length
        self.ch = ch
        self.batchnorm = nn.BatchNorm1d(28)
        self.batchnorm1 = nn.BatchNorm1d(336)
    
    def forward(self, x, mode=False):
        
        # convolve
        x = self.conv1(x)
        x = F.dropout(x, p=0.6, training=mode)
        x = F.max_pool1d(F.relu(x),4)
        x = x.view(-1, (self.length-2)*self.ch//4)
        x = self.linear1(x)
        x = F.relu(x)

        x = self.output(x)
#         x = F.dropout(x, p=0.5, training=mode)



        return x

# %%
importlib.reload(bci)

# construct and train model
model = ConvNet(num_channel, signal_len, 3)
# model = Net(num_channel, signal_len)

val_ratio = 0.10
val_ind = np.random.choice(tr_input.shape[0], int(tr_input.shape[0] * val_ratio), replace=False)
val_input = tr_input[val_ind[None]]
val_target = tr_target[val_ind[None]]
tr_ind = list(set(range(tr_input.shape[0])) - set(val_ind))
tr_input1 = tr_input[tr_ind]
tr_target1 = tr_target[tr_ind]

# print(tr_input1.shape)
# print(val_input.shape)

#v7_2: 86%
#v7_3: 86%

# tr_loss, te_loss = bci.train_model(model, tr_input, tr_target_onehot, 4, te_input, te_target_onehot, 4, 200)
# for i in range(50):

# tr_loss, te_loss = bci.train_model('v7_4.pth', model, tr_input, tr_target, 4, te_input, te_target, 4, 200)
tr_loss, te_loss = bci.train_model('v7_4.pth', model, tr_input1, tr_target1, 5, val_input, val_target, 41, te_input, te_target, 4, 200)
# Out:
# epoch  0
# tr acc = 0.51
# te acc = 0.51
# val acc = 0.37
# save the current best: 0.51
# epoch  1
# tr acc = 0.51
# te acc = 0.51
# val acc = 0.37
# epoch  2
# tr acc = 0.52
# te acc = 0.53
# val acc = 0.39
# save the current best: 0.53
# epoch  3
# tr acc = 0.54
# te acc = 0.53
# val acc = 0.39
# epoch  4
# tr acc = 0.62
# te acc = 0.57
# val acc = 0.51
# save the current best: 0.57
# epoch  5
# tr acc = 0.61
# te acc = 0.53
# val acc = 0.54
# epoch  6
# tr acc = 0.64
# te acc = 0.50
# val acc = 0.56
# epoch  7
# tr acc = 0.65
# te acc = 0.54
# val acc = 0.56
# epoch  8
# tr acc = 0.67
# te acc = 0.55
# val acc = 0.56
# epoch  9
# tr acc = 0.68
# te acc = 0.57
# val acc = 0.56
# epoch  10
# tr acc = 0.71
# te acc = 0.50
# val acc = 0.59
# epoch  11
# tr acc = 0.71
# te acc = 0.56
# val acc = 0.66
# epoch  12
# tr acc = 0.73
# te acc = 0.52
# val acc = 0.66
# epoch  13
# tr acc = 0.72
# te acc = 0.60
# val acc = 0.66
# save the current best: 0.60
# epoch  14
# tr acc = 0.76
# te acc = 0.59
# val acc = 0.68
# epoch  15
# tr acc = 0.76
# te acc = 0.60
# val acc = 0.68
# epoch  16
# tr acc = 0.77
# te acc = 0.58
# val acc = 0.68
# epoch  17
# tr acc = 0.81
# te acc = 0.64
# val acc = 0.76
# save the current best: 0.64
# epoch  18
# tr acc = 0.80
# te acc = 0.65
# val acc = 0.76
# save the current best: 0.65
# epoch  19
# tr acc = 0.83
# te acc = 0.70
# val acc = 0.85
# save the current best: 0.70
# epoch  20
# tr acc = 0.83
# te acc = 0.70
# val acc = 0.83
# epoch  21
# tr acc = 0.86
# te acc = 0.69
# val acc = 0.80
# epoch  22
# tr acc = 0.84
# te acc = 0.71
# val acc = 0.83
# save the current best: 0.71
# epoch  23
# tr acc = 0.86
# te acc = 0.71
# val acc = 0.85
# epoch  24
# tr acc = 0.88
# te acc = 0.73
# val acc = 0.83
# save the current best: 0.73
# epoch  25
# tr acc = 0.88
# te acc = 0.70
# val acc = 0.88
# epoch  26
# tr acc = 0.88
# te acc = 0.71
# val acc = 0.98
# epoch  27
# tr acc = 0.89
# te acc = 0.75
# val acc = 0.83
# save the current best: 0.75
# epoch  28
# tr acc = 0.89
# te acc = 0.80
# val acc = 0.83
# save the current best: 0.80
# epoch  29
# tr acc = 0.88
# te acc = 0.72
# val acc = 0.95
# epoch  30
# tr acc = 0.90
# te acc = 0.76
# val acc = 0.95
# epoch  31
# tr acc = 0.90
# te acc = 0.74
# val acc = 0.95
# epoch  32
# tr acc = 0.90
# te acc = 0.74
# val acc = 0.90
# epoch  33
# tr acc = 0.93
# te acc = 0.75
# val acc = 0.95
# epoch  34
# tr acc = 0.91
# te acc = 0.72
# val acc = 0.88
# epoch  35
# tr acc = 0.91
# te acc = 0.76
# val acc = 0.93
# epoch  36
# tr acc = 0.91
# te acc = 0.73
# val acc = 0.93
# epoch  37
# tr acc = 0.93
# te acc = 0.75
# val acc = 0.88
# epoch  38
# tr acc = 0.92
# te acc = 0.77
# val acc = 0.83
# epoch  39
# tr acc = 0.93
# te acc = 0.74
# val acc = 0.95
# epoch  40
# tr acc = 0.92
# te acc = 0.76
# val acc = 0.85
# epoch  41
# tr acc = 0.92
# te acc = 0.73
# val acc = 0.88
# epoch  42
# tr acc = 0.94
# te acc = 0.78
# val acc = 0.95
# epoch  43
# tr acc = 0.94
# te acc = 0.72
# val acc = 0.95
# epoch  44
# tr acc = 0.94
# te acc = 0.80
# val acc = 0.85
# epoch  45
# tr acc = 0.95
# te acc = 0.70
# val acc = 0.90
# epoch  46
# tr acc = 0.95
# te acc = 0.76
# val acc = 0.88
# epoch  47
# tr acc = 0.96
# te acc = 0.73
# val acc = 0.93
# epoch  48
# tr acc = 0.95
# te acc = 0.74
# val acc = 0.85
# epoch  49
# tr acc = 0.96
# te acc = 0.70
# val acc = 0.93
# epoch  50
# tr acc = 0.97
# te acc = 0.72
# val acc = 0.98
# epoch  51
# tr acc = 0.95
# te acc = 0.66
# val acc = 0.93
# epoch  52
# tr acc = 0.97
# te acc = 0.75
# val acc = 0.85
# epoch  53
# tr acc = 0.97
# te acc = 0.73
# val acc = 0.95
# epoch  54
# tr acc = 0.96
# te acc = 0.73
# val acc = 0.85
# epoch  55
# tr acc = 0.96
# te acc = 0.78
# val acc = 0.88
# epoch  56
# tr acc = 0.97
# te acc = 0.72
# val acc = 0.90
# epoch  57
# tr acc = 0.96
# te acc = 0.71
# val acc = 0.95
# epoch  58
# tr acc = 0.97
# te acc = 0.74
# val acc = 0.93
# epoch  59
# tr acc = 0.97
# te acc = 0.71
# val acc = 0.98
# epoch  60
# tr acc = 0.98
# te acc = 0.72
# val acc = 0.93
# epoch  61
# tr acc = 0.99
# te acc = 0.73
# val acc = 0.88
# epoch  62
# tr acc = 0.98
# te acc = 0.71
# val acc = 0.90
# epoch  63
# tr acc = 0.98
# te acc = 0.73
# val acc = 0.88
# epoch  64
# tr acc = 0.98
# te acc = 0.75
# val acc = 0.88
# epoch  65
# tr acc = 0.98
# te acc = 0.73
# val acc = 0.88
# epoch  66
# tr acc = 0.98
# te acc = 0.77
# val acc = 0.83
# epoch  67
# tr acc = 0.98
# te acc = 0.68
# val acc = 0.93
# epoch  68
# tr acc = 0.98
# te acc = 0.78
# val acc = 0.78
# epoch  69
# tr acc = 0.99
# te acc = 0.74
# val acc = 0.93
# epoch  70
# tr acc = 0.99
# te acc = 0.70
# val acc = 0.90
# epoch  71
# tr acc = 0.98
# te acc = 0.70
# val acc = 0.85
# epoch  72
# tr acc = 0.98
# te acc = 0.75
# val acc = 0.85
# epoch  73
# tr acc = 0.98
# te acc = 0.77
# val acc = 0.78
# epoch  74
# tr acc = 0.99
# te acc = 0.77
# val acc = 0.90
# epoch  75
# tr acc = 0.99
# te acc = 0.72
# val acc = 0.88
# epoch  76
# tr acc = 0.99
# te acc = 0.71
# val acc = 0.95
# epoch  77
# tr acc = 0.99
# te acc = 0.73
# val acc = 0.90
# epoch  78
# tr acc = 0.98
# te acc = 0.73
# val acc = 0.83
# epoch  79
# tr acc = 0.99
# te acc = 0.73
# val acc = 0.85
# epoch  80
# tr acc = 0.99
# te acc = 0.69
# val acc = 0.85
# epoch  81
# tr acc = 0.99
# te acc = 0.69
# val acc = 0.88
# epoch  82
# tr acc = 0.99
# te acc = 0.73
# val acc = 0.85
# epoch  83
# tr acc = 0.97
# te acc = 0.72
# val acc = 0.88
# epoch  84
# tr acc = 0.98
# te acc = 0.73
# val acc = 0.88
# epoch  85
# tr acc = 0.99
# te acc = 0.70
# val acc = 0.85
# epoch  86
# tr acc = 0.99
# te acc = 0.71
# val acc = 0.88
# epoch  87
# tr acc = 0.99
# te acc = 0.71
# val acc = 0.90
# epoch  88
# tr acc = 0.99
# te acc = 0.68
# val acc = 0.93
# epoch  89
# tr acc = 0.99
# te acc = 0.70
# val acc = 0.85
# epoch  90
# tr acc = 0.99
# te acc = 0.68
# val acc = 0.85
# epoch  91
# tr acc = 0.99
# te acc = 0.73
# val acc = 0.88
# epoch  92
# tr acc = 1.00
# te acc = 0.70
# val acc = 0.88
# epoch  93
# tr acc = 0.99
# te acc = 0.71
# val acc = 0.90
# epoch  94
# tr acc = 0.99
# te acc = 0.72
# val acc = 0.83
# epoch  95
# tr acc = 1.00
# te acc = 0.72
# val acc = 0.85
# epoch  96
# tr acc = 0.99
# te acc = 0.73
# val acc = 0.90
# epoch  97
# tr acc = 0.99
# te acc = 0.71
# val acc = 0.88
# epoch  98
# tr acc = 0.99
# te acc = 0.73
# val acc = 0.80
# epoch  99
# tr acc = 1.00
# te acc = 0.68
# val acc = 0.80
# epoch  100
# tr acc = 1.00
# te acc = 0.74
# val acc = 0.83
# epoch  101
# tr acc = 0.97
# te acc = 0.73
# val acc = 0.80
# epoch  102
# tr acc = 1.00
# te acc = 0.68
# val acc = 0.85
# epoch  103
# tr acc = 0.99
# te acc = 0.75
# val acc = 0.80
# epoch  104
# tr acc = 0.99
# te acc = 0.73
# val acc = 0.85
# epoch  105
# tr acc = 1.00
# te acc = 0.70
# val acc = 0.80
# epoch  106
# tr acc = 0.99
# te acc = 0.74
# val acc = 0.83
# epoch  107
# tr acc = 0.99
# te acc = 0.73
# val acc = 0.88
# epoch  108
# tr acc = 1.00
# te acc = 0.69
# val acc = 0.88
# epoch  109
# tr acc = 0.99
# te acc = 0.65
# val acc = 0.83
# epoch  110
# tr acc = 1.00
# te acc = 0.71
# val acc = 0.80
# epoch  111
# tr acc = 0.99
# te acc = 0.71
# val acc = 0.85
# epoch  112
# tr acc = 0.99
# te acc = 0.70
# val acc = 0.78
# epoch  113
# tr acc = 0.98
# te acc = 0.70
# val acc = 0.85
# epoch  114
# tr acc = 0.96
# te acc = 0.72
# val acc = 0.78
# epoch  115
# tr acc = 0.99
# te acc = 0.71
# val acc = 0.85
# epoch  116
# tr acc = 0.99
# te acc = 0.76
# val acc = 0.85
# epoch  117
# tr acc = 1.00
# te acc = 0.72
# val acc = 0.85
# epoch  118
# tr acc = 1.00
# te acc = 0.72
# val acc = 0.78
# epoch  119
# tr acc = 0.99
# te acc = 0.72
# val acc = 0.80
# epoch  120
# tr acc = 0.99
# te acc = 0.70
# val acc = 0.80
# epoch  121
# tr acc = 0.99
# te acc = 0.73
# val acc = 0.80
# epoch  122
# tr acc = 1.00
# te acc = 0.72
# val acc = 0.73
# epoch  123
# tr acc = 0.99
# te acc = 0.69
# val acc = 0.80
# epoch  124
# tr acc = 1.00
# te acc = 0.71
# val acc = 0.85
# epoch  125
# tr acc = 0.99
# te acc = 0.74
# val acc = 0.80
# epoch  126
# tr acc = 1.00
# te acc = 0.73
# val acc = 0.88
# epoch  127
# tr acc = 1.00
# te acc = 0.72
# val acc = 0.85
# epoch  128
# tr acc = 0.99
# te acc = 0.72
# val acc = 0.83
# epoch  129
# tr acc = 1.00
# te acc = 0.71
# val acc = 0.83
# epoch  130
# tr acc = 0.99
# te acc = 0.72
# val acc = 0.83
# epoch  131
# tr acc = 1.00
# te acc = 0.74
# val acc = 0.85
# epoch  132
# tr acc = 0.99
# te acc = 0.71
# val acc = 0.85
# epoch  133
# tr acc = 0.99
# te acc = 0.72
# val acc = 0.85
# epoch  134
# tr acc = 0.99
# te acc = 0.74
# val acc = 0.88
# epoch  135
# tr acc = 1.00
# te acc = 0.73
# val acc = 0.85
# epoch  136
# tr acc = 1.00
# te acc = 0.70
# val acc = 0.85
# epoch  137
# tr acc = 1.00
# te acc = 0.73
# val acc = 0.80
# epoch  138
# tr acc = 0.98
# te acc = 0.68
# val acc = 0.78
# epoch  139
# tr acc = 0.98
# te acc = 0.73
# val acc = 0.85
# epoch  140
# tr acc = 1.00
# te acc = 0.73
# val acc = 0.83
# epoch  141
# tr acc = 0.99
# te acc = 0.71
# val acc = 0.80
# epoch  142
# tr acc = 0.99
# te acc = 0.72
# val acc = 0.83
# epoch  143
# tr acc = 1.00
# te acc = 0.71
# val acc = 0.85
# epoch  144
# tr acc = 1.00
# te acc = 0.71
# val acc = 0.83
# epoch  145
# tr acc = 1.00
# te acc = 0.72
# val acc = 0.83
# epoch  146
# tr acc = 0.98
# te acc = 0.71
# val acc = 0.83
# epoch  147
# tr acc = 0.99
# te acc = 0.70
# val acc = 0.83
# epoch  148
# tr acc = 0.99
# te acc = 0.70
# val acc = 0.73
# epoch  149
# tr acc = 0.99
# te acc = 0.71
# val acc = 0.76
# epoch  150
# tr acc = 0.99
# te acc = 0.74
# val acc = 0.76
# epoch  151
# tr acc = 0.98
# te acc = 0.72
# val acc = 0.80
# epoch  152
# tr acc = 1.00
# te acc = 0.70
# val acc = 0.88
# epoch  153
# tr acc = 0.98
# te acc = 0.70
# val acc = 0.80
# epoch  154
# tr acc = 0.99
# te acc = 0.68
# val acc = 0.83
# epoch  155
# tr acc = 1.00
# te acc = 0.70
# val acc = 0.80
# epoch  156
# tr acc = 1.00
# te acc = 0.73
# val acc = 0.78
# epoch  157
# tr acc = 1.00
# te acc = 0.73
# val acc = 0.83
# epoch  158
# tr acc = 1.00
# te acc = 0.75
# val acc = 0.83
# epoch  159
# tr acc = 1.00
# te acc = 0.72
# val acc = 0.80
# epoch  160
# tr acc = 0.97
# te acc = 0.72
# val acc = 0.73
# epoch  161
# tr acc = 0.98
# te acc = 0.73
# val acc = 0.80
# epoch  162
# tr acc = 0.99
# te acc = 0.74
# val acc = 0.78
# epoch  163
# tr acc = 1.00
# te acc = 0.77
# val acc = 0.80
# epoch  164
# tr acc = 0.99
# te acc = 0.72
# val acc = 0.80
# epoch  165
# tr acc = 1.00
# te acc = 0.74
# val acc = 0.76
# epoch  166
# tr acc = 1.00
# te acc = 0.70
# val acc = 0.78
# epoch  167
# tr acc = 1.00
# te acc = 0.72
# val acc = 0.85
# epoch  168
# tr acc = 1.00
# te acc = 0.70
# val acc = 0.85
# epoch  169
# tr acc = 1.00
# te acc = 0.71
# val acc = 0.90
# epoch  170
# tr acc = 1.00
# te acc = 0.75
# val acc = 0.85
# epoch  171
# tr acc = 1.00
# te acc = 0.75
# val acc = 0.83
# epoch  172
# tr acc = 1.00
# te acc = 0.73
# val acc = 0.83
# epoch  173
# tr acc = 1.00
# te acc = 0.72
# val acc = 0.76
# epoch  174
# tr acc = 0.99
# te acc = 0.74
# val acc = 0.71
# epoch  175
# tr acc = 0.99
# te acc = 0.72
# val acc = 0.83
# epoch  176
# tr acc = 0.98
# te acc = 0.71
# val acc = 0.80
# epoch  177
# tr acc = 1.00
# te acc = 0.65
# val acc = 0.90
# epoch  178
# tr acc = 1.00
# te acc = 0.70
# val acc = 0.88
# epoch  179
# tr acc = 1.00
# te acc = 0.74
# val acc = 0.83
# epoch  180
# tr acc = 1.00
# te acc = 0.74
# val acc = 0.76
# epoch  181
# tr acc = 0.98
# te acc = 0.69
# val acc = 0.83
# epoch  182
# tr acc = 1.00
# te acc = 0.68
# val acc = 0.88
# epoch  183
# tr acc = 1.00
# te acc = 0.76
# val acc = 0.78
# epoch  184
# tr acc = 0.99
# te acc = 0.73
# val acc = 0.85
# epoch  185
# tr acc = 1.00
# te acc = 0.73
# val acc = 0.83
# epoch  186
# tr acc = 1.00
# te acc = 0.70
# val acc = 0.85
# epoch  187
# tr acc = 1.00
# te acc = 0.71
# val acc = 0.78
# epoch  188
# tr acc = 1.00
# te acc = 0.64
# val acc = 0.85
# epoch  189
# tr acc = 1.00
# te acc = 0.71
# val acc = 0.88
# epoch  190
# tr acc = 0.98
# te acc = 0.78
# val acc = 0.73
# epoch  191
# tr acc = 1.00
# te acc = 0.73
# val acc = 0.80
# epoch  192
# tr acc = 0.98
# te acc = 0.71
# val acc = 0.78
# epoch  193
# tr acc = 0.99
# te acc = 0.72
# val acc = 0.80
# epoch  194
# tr acc = 1.00
# te acc = 0.71
# val acc = 0.83
# epoch  195
# tr acc = 0.99
# te acc = 0.73
# val acc = 0.80
# epoch  196
# tr acc = 0.95
# te acc = 0.74
# val acc = 0.68
# epoch  197
# tr acc = 1.00
# te acc = 0.67
# val acc = 0.80
# epoch  198
# tr acc = 1.00
# te acc = 0.72
# val acc = 0.76
# epoch  199
# tr acc = 0.99
# te acc = 0.70
# val acc = 0.76

# %%
# torch.save(model.state_dict(), os.getcwd() + "v1.pth")

# compute train and test errors
# nb_tr_errors = bci.compute_nb_errors(model, tr_input, tr_target_onehot, 4)
# nb_te_errors = bci.compute_nb_errors(model, te_input, te_target_onehot, 4)

# num_correct = np.sum((torch.max(F.softmax(model(tr_input), 1), 1)[1] == tr_target).data.numpy())
# print('tr acc = {:0.2f}'.format(num_correct/tr_target.shape[0]))
# num_correct = np.sum((torch.max(F.softmax(model(te_input), 1), 1)[1] == te_target).data.numpy())
# print('te acc = {:0.2f}'.format(num_correct/te_target.shape[0]))

# print('tr error {:0.2f}% {:d}/{:d}'.format((100 * nb_tr_errors) / tr_input.size(0), nb_tr_errors, tr_input.size(0)))
# print('te error {:0.2f}% {:d}/{:d}'.format((100 * nb_te_errors) / te_input.size(0), nb_te_errors, te_input.size(0)))

# %%
import matplotlib as mpl
mpl.rcParams['figure.dpi']= 150

plt.figure()
plt.plot(tr_loss, label='training loss')
plt.plot(te_loss, label='validation loss')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ### record

# %%
# samples = tr_input[0,:,:].numpy()
# for sample in samples:
# #     sample = sample[0,:]
# #     sample = samples[0,0,:]
#     f, (ax1, ax2) = plt.subplots(1, 2, figsize=(20,6))
#     ax1.plot(sample)
#     ax2.plot(abs(np.fft.fft(sample)))
#     plt.show()

#     N = 10
#     sample_filtered = np.convolve(sample, np.ones((N,))/N, mode='valid')

#     f, (ax1, ax2) = plt.subplots(1, 2, figsize=(20,6))
#     ax1.plot(sample_filtered)
#     ax2.plot(abs(np.fft.fft(sample_filtered)))
#     plt.show()

# %%
# # size of moving average filter
# N = 10 
# # downsampling
# Nd = 5
# sample = lowpass_filtering(tr_input[0,0,:].numpy(), N)[::Nd]

# tr_input_filtered = torch.zeros([tr_input.shape[0],tr_input.shape[1],sample.shape[0]])
# te_input_filtered = torch.zeros([te_input.shape[0],te_input.shape[1],sample.shape[0]])

# for idx1, data in enumerate(tr_input):
#     for idx2, channel in enumerate(data):
#         tr_input_filtered[idx1, idx2, :] = torch.from_numpy(lowpass_filtering(channel.numpy(), 10)[::Nd])

# for idx1, data in enumerate(te_input):
#     for idx2, channel in enumerate(data):
#         te_input_filtered[idx1, idx2, :] = torch.from_numpy(lowpass_filtering(channel.numpy(), 10)[::Nd])
# tr_input = tr_input_filtered
# te_input = te_input_filtered

# %%
# sample = dc_blocker(tr_input[0,0,:].numpy())

# tr_input_filtered = torch.zeros([tr_input.shape[0],tr_input.shape[1],sample.shape[0]])
# te_input_filtered = torch.zeros([te_input.shape[0],te_input.shape[1],sample.shape[0]])

# for idx1, data in enumerate(tr_input):
#     for idx2, channel in enumerate(data):
#         tr_input_filtered[idx1, idx2, :] = torch.from_numpy(dc_blocker(channel.numpy()))

# for idx1, data in enumerate(te_input):
#     for idx2, channel in enumerate(data):
#         te_input_filtered[idx1, idx2, :] = torch.from_numpy(dc_blocker(channel.numpy()))


# tr_input = tr_input_filtered
# te_input = te_input_filtered

# sample = tr_input[1,6,:].numpy()
# f, (ax1, ax2) = plt.subplots(1, 2, figsize=(20,6))
# ax1.plot(sample)
# sample_dc = dc_blocker(sample)
# ax2.plot(sample_dc)
# plt.show()

# %%
# sample = tr_input[:,11,:].numpy()
# for channel in sample[0:4]:
# #     plt.plot(channel)
#     f, (ax1, ax2) = plt.subplots(1, 2, figsize=(20,6))
# #     ax1.plot(channel)
#     sample_fft = np.fft.fft(channel)
# #     ax1.plot(abs(sample_fft))
#     ax1.plot(channel)
# #     ax2.plot(np.angle(sample_fft))
#     ax2.plot(abs(np.fft.fft(channel)))

#     plt.show()

# %%
# def fft_data(signal, size = 20):
#     sample_fft = np.fft.fft(signal)
#     sample_angle = np.angle(sample_fft)
    
#     return np.append(abs(sample_fft)[0:size],sample_angle[0:size])


# sample = fft_data(tr_input[0,0,:].numpy())

# tr_input_filtered = torch.zeros([tr_input.shape[0],tr_input.shape[1],sample.shape[0]])
# te_input_filtered = torch.zeros([te_input.shape[0],te_input.shape[1],sample.shape[0]])

# for idx1, data in enumerate(tr_input):
#     for idx2, channel in enumerate(data):
#         tr_input_filtered[idx1, idx2, :] = torch.from_numpy(fft_data(channel.numpy()))

# for idx1, data in enumerate(te_input):
#     for idx2, channel in enumerate(data):
#         te_input_filtered[idx1, idx2, :] = torch.from_numpy(fft_data(channel.numpy()))


# tr_input = tr_input_filtered
# te_input = te_input_filtered

# %%
# epoch = 400
# lr = 1e-2


# net = Net(num_channel, signal_len)

# loss_func = nn.CrossEntropyLoss()
# optimizer = torch.optim.SGD(net.parameters(), lr=lr)

# tr_loss_all = []
# te_loss_all = []

# for e in range(0, epoch):
#     tr_loss = 0
#     te_loss = 0
    
#     prediction = net(tr_input)
#     loss = loss_func(prediction, tr_target)
#     tr_loss = loss.data[0]
#     optimizer.zero_grad()
#     loss.backward()
#     optimizer.step()
    
#     prediction = net(te_input)
#     loss = loss_func(prediction, te_target)
#     te_loss = loss.data[0]
    
#     print('epoch {:d} tr loss {:0.2f} te loss {:0.2f}'.format(e, tr_loss, te_loss))

# num_correct = np.sum((torch.max(F.softmax(model(tr_input), 1), 1)[1] == tr_target).data.numpy())
# print('tr acc = {:0.2f}'.format(num_correct/tr_target.shape[0]))
# num_correct = np.sum((torch.max(F.softmax(model(te_input), 1), 1)[1] == te_target).data.numpy())
# print('te acc = {:0.2f}'.format(num_correct/te_target.shape[0]))
# # num_correct = float(torch.sum(torch.max(F.softmax(net(tr_input), 1), 1)[1] == tr_target).data)
# # print('tr acc = {:0.2f}'.format(num_correct/tr_target.shape[0]))
# # num_correct = float(torch.sum(torch.max(F.softmax(net(te_input), 1), 1)[1] == te_target).data)
# # print('tr acc = {:0.2f}'.format(num_correct/te_target.shape[0]))
