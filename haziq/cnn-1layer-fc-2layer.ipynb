# %%
import os
import numpy as np
import matplotlib.pyplot as plt

import dlc_bci as bci
from dlc_practical_prologue import *

import torch
from torch import nn
from torch.nn import functional as F
from torch.autograd import Variable

# %% [markdown]
# Load dataset

# %%
# Load dataset
tr_input, tr_target = bci.load("bci", train=True, one_khz=False)
te_input, te_target = bci.load("bci", train=False, one_khz=False)

# Prepare onehot vector for computation of loss
tr_target_onehot = convert_to_one_hot_labels(tr_input, tr_target)
te_target_onehot = convert_to_one_hot_labels(te_input, te_target)

# %% [markdown]
# Standardize

# %%
# normalize
tr_input = torch.nn.functional.normalize(tr_input, p=2, dim=0) 
te_input = torch.nn.functional.normalize(te_input, p=2, dim=0) 

# Convert to 4D tensor [dataset size, number of channels, rows, cols]
tr_input = tr_input[:, np.newaxis, :, :]
te_input = te_input[:, np.newaxis, :, :]

# Convert to pytorch variable
tr_input, tr_target, tr_target_onehot = Variable(tr_input), Variable(tr_target), Variable(tr_target_onehot)
te_input, te_target, te_target_onehot = Variable(te_input), Variable(te_target), Variable(te_target_onehot)

# %% [markdown]
# Output of NN is still a vector (cross entropy loss handles log-softmax)

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1a = nn.Conv2d(in_channels=1, out_channels=2, kernel_size=(28, 5), stride=2)
        self.conv1b = nn.Conv2d(in_channels=1, out_channels=2, kernel_size=(28, 10), stride=2)
        self.conv1c = nn.Conv2d(in_channels=1, out_channels=2, kernel_size=(28, 15), stride=2)
        
        self.fc1 = nn.Linear(124, 200)
        self.fc2 = nn.Linear(200, 2)
        
    def forward(self, x, mode=False):
        
        # convolve
        x1a = self.conv1a(x)
        x1b = self.conv1b(x)
        x1c = self.conv1c(x)
        
        # reshape and concat
        x = torch.cat((x1a.view(x1a.size(0), -1), x1b.view(x1b.size(0), -1), x1c.view(x1c.size(0), -1)), 1)  
        
        # fc
        x = F.relu(self.fc1(x))
        x = F.dropout(x, p=0.5, training=mode)
        x = self.fc2(x)
        return x

# %%
# construct and train model
model = Net()
tr_loss, te_loss = bci.train_model(model, tr_input, tr_target, 4, te_input, te_target, 4, 200)
#torch.save(model.state_dict(), os.getcwd() + "v1.pth")

# compute train and test errors
nb_tr_errors = bci.compute_nb_errors(model, tr_input, tr_target_onehot, 4, True)
nb_te_errors = bci.compute_nb_errors(model, te_input, te_target_onehot, 4, False)

print('tr error {:0.2f}% {:d}/{:d}'.format((100 * nb_tr_errors) / tr_input.size(0), nb_tr_errors, tr_input.size(0)))
print('te error {:0.2f}% {:d}/{:d}'.format((100 * nb_te_errors) / te_input.size(0), nb_te_errors, te_input.size(0)))
# Out:
# epoch 0 tr loss 55.15 te loss 17.43
# epoch 1 tr loss 54.92 te loss 17.46
# epoch 2 tr loss 55.17 te loss 17.43
# epoch 3 tr loss 55.04 te loss 17.41
# epoch 4 tr loss 55.04 te loss 17.44
# epoch 5 tr loss 55.22 te loss 17.47
# epoch 6 tr loss 55.14 te loss 17.46
# epoch 7 tr loss 55.02 te loss 17.47
# epoch 8 tr loss 55.02 te loss 17.46
# epoch 9 tr loss 55.00 te loss 17.49
# epoch 10 tr loss 54.95 te loss 17.53
# epoch 11 tr loss 54.83 te loss 17.57
# epoch 12 tr loss 54.67 te loss 17.62
# epoch 13 tr loss 54.43 te loss 17.75
# epoch 14 tr loss 54.70 te loss 17.60
# epoch 15 tr loss 54.69 te loss 17.69
# epoch 16 tr loss 54.47 te loss 17.61
# epoch 17 tr loss 54.23 te loss 17.61
# epoch 18 tr loss 54.20 te loss 17.82
# epoch 19 tr loss 53.82 te loss 17.77
# epoch 20 tr loss 54.06 te loss 17.73
# epoch 21 tr loss 53.23 te loss 17.87
# epoch 22 tr loss 53.84 te loss 17.93
# epoch 23 tr loss 53.03 te loss 17.80
# epoch 24 tr loss 53.65 te loss 17.81
# epoch 25 tr loss 52.92 te loss 17.77
# epoch 26 tr loss 52.61 te loss 18.09
# epoch 27 tr loss 52.12 te loss 17.95
# epoch 28 tr loss 52.62 te loss 17.42
# epoch 29 tr loss 51.00 te loss 17.63
# epoch 30 tr loss 51.11 te loss 17.37
# epoch 31 tr loss 49.44 te loss 17.97
# epoch 32 tr loss 50.31 te loss 17.03
# epoch 33 tr loss 48.86 te loss 17.27
# epoch 34 tr loss 47.96 te loss 17.29
# epoch 35 tr loss 47.38 te loss 16.66
# epoch 36 tr loss 46.37 te loss 16.14
# epoch 37 tr loss 46.18 te loss 15.93
# epoch 38 tr loss 43.22 te loss 16.93
# epoch 39 tr loss 43.92 te loss 16.50
# epoch 40 tr loss 40.15 te loss 16.80
# epoch 41 tr loss 40.92 te loss 14.43
# epoch 42 tr loss 38.26 te loss 15.70
# epoch 43 tr loss 37.55 te loss 15.87
# epoch 44 tr loss 36.32 te loss 17.32
# epoch 45 tr loss 34.17 te loss 15.61
# epoch 46 tr loss 36.24 te loss 15.20
# epoch 47 tr loss 36.48 te loss 15.95
# epoch 48 tr loss 32.63 te loss 16.73
# epoch 49 tr loss 32.58 te loss 16.55
# epoch 50 tr loss 31.33 te loss 16.49
# epoch 51 tr loss 31.57 te loss 17.00
# epoch 52 tr loss 30.88 te loss 17.18
# epoch 53 tr loss 30.64 te loss 16.34
# epoch 54 tr loss 28.77 te loss 16.75
# epoch 55 tr loss 29.53 te loss 17.05
# epoch 56 tr loss 28.53 te loss 17.35
# epoch 57 tr loss 29.14 te loss 18.87
# epoch 58 tr loss 26.61 te loss 21.67
# epoch 59 tr loss 26.73 te loss 18.54
# epoch 60 tr loss 25.69 te loss 21.63
# epoch 61 tr loss 25.39 te loss 19.91
# epoch 62 tr loss 24.87 te loss 21.09
# epoch 63 tr loss 24.47 te loss 21.21
# epoch 64 tr loss 23.52 te loss 23.50
# epoch 65 tr loss 23.91 te loss 25.51
# epoch 66 tr loss 20.62 te loss 24.83
# epoch 67 tr loss 23.49 te loss 24.23
# epoch 68 tr loss 20.06 te loss 25.50
# epoch 69 tr loss 21.56 te loss 24.91
# epoch 70 tr loss 26.01 te loss 24.50
# epoch 71 tr loss 22.14 te loss 25.11
# epoch 72 tr loss 20.85 te loss 26.44
# epoch 73 tr loss 18.93 te loss 26.52
# epoch 74 tr loss 21.86 te loss 28.77
# epoch 75 tr loss 19.84 te loss 26.60
# epoch 76 tr loss 19.09 te loss 25.48
# epoch 77 tr loss 21.23 te loss 26.63
# epoch 78 tr loss 18.75 te loss 26.62
# epoch 79 tr loss 17.15 te loss 25.40
# epoch 80 tr loss 16.17 te loss 25.35
# epoch 81 tr loss 16.86 te loss 31.10
# epoch 82 tr loss 16.12 te loss 33.08
# epoch 83 tr loss 15.69 te loss 36.38
# epoch 84 tr loss 16.25 te loss 31.25
# epoch 85 tr loss 17.98 te loss 28.77
# epoch 86 tr loss 13.44 te loss 35.36
# epoch 87 tr loss 17.75 te loss 28.88
# epoch 88 tr loss 16.70 te loss 29.42
# epoch 89 tr loss 15.03 te loss 34.22
# epoch 90 tr loss 12.03 te loss 34.98
# epoch 91 tr loss 10.98 te loss 45.89
# epoch 92 tr loss 14.36 te loss 39.47
# epoch 93 tr loss 13.55 te loss 41.02
# epoch 94 tr loss 10.15 te loss 44.09
# epoch 95 tr loss 11.53 te loss 44.43
# epoch 96 tr loss 8.88 te loss 36.15
# epoch 97 tr loss 12.94 te loss 55.42
# epoch 98 tr loss 11.17 te loss 32.95
# epoch 99 tr loss 9.52 te loss 34.65
# epoch 100 tr loss 11.84 te loss 34.70
# epoch 101 tr loss 9.46 te loss 40.71
# epoch 102 tr loss 9.15 te loss 40.26
# epoch 103 tr loss 11.11 te loss 40.45
# epoch 104 tr loss 7.38 te loss 41.93
# epoch 105 tr loss 7.43 te loss 37.56
# epoch 106 tr loss 7.75 te loss 34.52
# epoch 107 tr loss 16.47 te loss 35.71
# epoch 108 tr loss 12.36 te loss 30.74
# epoch 109 tr loss 8.77 te loss 34.26
# epoch 110 tr loss 6.50 te loss 35.90
# epoch 111 tr loss 5.67 te loss 40.38
# epoch 112 tr loss 7.55 te loss 34.59
# epoch 113 tr loss 6.22 te loss 44.17
# epoch 114 tr loss 13.09 te loss 35.73
# epoch 115 tr loss 6.08 te loss 35.28
# epoch 116 tr loss 7.34 te loss 54.47
# epoch 117 tr loss 4.98 te loss 46.80
# epoch 118 tr loss 4.30 te loss 44.25
# epoch 119 tr loss 4.00 te loss 44.10
# epoch 120 tr loss 3.92 te loss 44.38
# epoch 121 tr loss 3.95 te loss 38.66
# epoch 122 tr loss 6.34 te loss 43.13
# epoch 123 tr loss 8.96 te loss 42.37
# epoch 124 tr loss 5.15 te loss 41.13
# epoch 125 tr loss 23.05 te loss 51.27
# epoch 126 tr loss 6.25 te loss 51.75
# epoch 127 tr loss 4.44 te loss 41.52
# epoch 128 tr loss 4.51 te loss 62.88
# epoch 129 tr loss 4.66 te loss 45.60
# epoch 130 tr loss 3.20 te loss 41.29
# epoch 131 tr loss 5.82 te loss 47.86
# epoch 132 tr loss 6.09 te loss 42.65
# epoch 133 tr loss 4.01 te loss 44.07
# epoch 134 tr loss 3.36 te loss 44.56
# epoch 135 tr loss 2.40 te loss 43.56
# epoch 136 tr loss 3.49 te loss 43.81
# epoch 137 tr loss 2.72 te loss 42.02
# epoch 138 tr loss 1.88 te loss 47.77
# epoch 139 tr loss 1.82 te loss 45.97
# epoch 140 tr loss 3.66 te loss 46.73
# epoch 141 tr loss 4.23 te loss 44.26
# epoch 142 tr loss 2.41 te loss 46.62
# epoch 143 tr loss 1.99 te loss 47.79
# epoch 144 tr loss 7.45 te loss 38.64
# epoch 145 tr loss 2.07 te loss 43.45
# epoch 146 tr loss 1.62 te loss 48.14
# epoch 147 tr loss 1.77 te loss 49.40
# epoch 148 tr loss 1.58 te loss 45.95
# epoch 149 tr loss 1.59 te loss 47.64
# epoch 150 tr loss 1.29 te loss 48.23
# epoch 151 tr loss 1.65 te loss 44.89
# epoch 152 tr loss 2.41 te loss 68.22
# epoch 153 tr loss 3.00 te loss 52.75
# epoch 154 tr loss 2.15 te loss 56.08
# epoch 155 tr loss 1.82 te loss 45.40
# epoch 156 tr loss 1.56 te loss 42.02
# epoch 157 tr loss 1.46 te loss 44.75
# epoch 158 tr loss 5.29 te loss 48.46
# epoch 159 tr loss 2.69 te loss 48.55
# epoch 160 tr loss 1.92 te loss 45.06
# epoch 161 tr loss 3.57 te loss 46.94
# epoch 162 tr loss 1.23 te loss 46.49
# epoch 163 tr loss 0.97 te loss 50.03
# epoch 164 tr loss 1.41 te loss 47.47
# epoch 165 tr loss 1.57 te loss 65.91
# epoch 166 tr loss 1.60 te loss 54.47
# epoch 167 tr loss 1.27 te loss 51.36
# epoch 168 tr loss 0.90 te loss 52.52
# epoch 169 tr loss 0.94 te loss 50.18
# epoch 170 tr loss 1.49 te loss 54.16
# epoch 171 tr loss 0.55 te loss 57.30
# epoch 172 tr loss 0.92 te loss 52.89
# epoch 173 tr loss 0.89 te loss 60.90
# epoch 174 tr loss 0.51 te loss 54.15
# epoch 175 tr loss 1.17 te loss 71.79
# epoch 176 tr loss 1.05 te loss 54.27
# epoch 177 tr loss 0.72 te loss 59.98
# epoch 178 tr loss 0.79 te loss 49.10
# epoch 179 tr loss 1.20 te loss 53.25
# epoch 180 tr loss 0.70 te loss 55.00
# epoch 181 tr loss 0.42 te loss 54.66
# epoch 182 tr loss 0.73 te loss 54.37
# epoch 183 tr loss 0.53 te loss 51.73
# epoch 184 tr loss 0.61 te loss 53.78
# epoch 185 tr loss 0.42 te loss 55.64
# epoch 186 tr loss 0.79 te loss 60.20
# epoch 187 tr loss 0.89 te loss 80.45
# epoch 188 tr loss 0.93 te loss 53.75
# epoch 189 tr loss 0.56 te loss 56.34
# epoch 190 tr loss 0.60 te loss 55.97
# epoch 191 tr loss 1.16 te loss 59.84
# epoch 192 tr loss 2.30 te loss 55.98
# epoch 193 tr loss 0.60 te loss 56.56
# epoch 194 tr loss 0.43 te loss 57.51
# epoch 195 tr loss 0.68 te loss 61.01
# epoch 196 tr loss 0.49 te loss 59.93
# epoch 197 tr loss 0.48 te loss 56.10
# epoch 198 tr loss 5.26 te loss 63.65
# epoch 199 tr loss 3.07 te loss 93.63
# tr error 15.19% 48/316
# te error 32.00% 32/100

# %%
import matplotlib as mpl
mpl.rcParams['figure.dpi']= 150

plt.figure()
plt.plot(tr_loss, label='training loss')
plt.plot(te_loss, label='validation loss')
plt.legend(loc='upper left')
