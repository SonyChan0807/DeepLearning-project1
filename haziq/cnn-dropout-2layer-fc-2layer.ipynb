# %%
import os
import numpy as np
import matplotlib.pyplot as plt

import dlc_bci as bci
from dlc_practical_prologue import *

import torch
from torch import nn
from torch.nn import functional as F
from torch.autograd import Variable

# %% [markdown]
# Load dataset

# %%
# Load dataset
tr_input, tr_target = bci.load("bci", train=True, one_khz=False)
te_input, te_target = bci.load("bci", train=False, one_khz=False)

# Prepare onehot vector for computation of loss
tr_target_onehot = convert_to_one_hot_labels(tr_input, tr_target)
te_target_onehot = convert_to_one_hot_labels(te_input, te_target)

# %% [markdown]
# Standardize

# %%
# normalize
tr_input = torch.nn.functional.normalize(tr_input, p=2, dim=0) 
te_input = torch.nn.functional.normalize(te_input, p=2, dim=0) 

# Convert to 4D tensor [dataset size, number of channels (1), rows (28), cols (50)]
tr_input = tr_input[:, np.newaxis, :, :]
te_input = te_input[:, np.newaxis, :, :]

# Reshape to [dataset size, 28, 1, 50]
tr_input = np.transpose(tr_input, (0, 2, 1, 3))
te_input = np.transpose(te_input, (0, 2, 1, 3))

# Convert to pytorch variable
tr_input, tr_target, tr_target_onehot = Variable(tr_input), Variable(tr_target), Variable(tr_target_onehot)
te_input, te_target, te_target_onehot = Variable(te_input), Variable(te_target), Variable(te_target_onehot)

# %% [markdown]
# Output of NN is still a vector (cross entropy loss handles log-softmax)

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1a = nn.Conv2d(in_channels=28, out_channels=2, kernel_size=(1, 5), stride=2)
        self.conv1b = nn.Conv2d(in_channels=28, out_channels=2, kernel_size=(1, 10), stride=2)
        self.conv1c = nn.Conv2d(in_channels=28, out_channels=2, kernel_size=(1, 15), stride=2)
        
        self.conv2a = nn.Conv2d(in_channels=1, out_channels=2, kernel_size=(1, 5), stride=2)
        self.conv2b = nn.Conv2d(in_channels=1, out_channels=2, kernel_size=(1, 10), stride=2)
        self.conv2c = nn.Conv2d(in_channels=1, out_channels=2, kernel_size=(1, 15), stride=2)
        
        self.fc1 = nn.Linear(346, 200)
        self.fc2 = nn.Linear(200, 2)
        
    def forward(self, x, mode=False):
        
        # convolve
        x1a = F.dropout2d(self.conv1a(x), mode)
        x1b = F.dropout2d(self.conv1b(x), mode)
        x1c = F.dropout2d(self.conv1c(x), mode)
                
        # reshape and concat
        x = torch.cat((x1a.view(x1a.size(0), -1), x1b.view(x1b.size(0), -1), x1c.view(x1c.size(0), -1)), 1)    
        x = x.view(x.size(0), 1, 1,-1)
        
        # convolve
        x2a = self.conv2a(x)
        x2b = self.conv2b(x)
        x2c = self.conv2c(x)
        
        x = torch.cat((x2a.view(x2a.size(0), -1), x2b.view(x2b.size(0), -1), x2c.view(x2c.size(0), -1)), 1)
        
        # fc
        x = F.relu(self.fc1(x))
        x = F.dropout(x, p=0.5, training=mode)
        x = self.fc2(x)
        return x

# %%
# construct and train model
model = Net()
tr_loss, te_loss = bci.train_model(model, tr_input, tr_target, 4, te_input, te_target, 4, 200)
#torch.save(model.state_dict(), os.getcwd() + "v1.pth")

# compute train and test errors
nb_tr_errors = bci.compute_nb_errors(model, tr_input, tr_target_onehot, 4, True)
nb_te_errors = bci.compute_nb_errors(model, te_input, te_target_onehot, 4, False)

print('tr error {:0.2f}% {:d}/{:d}'.format((100 * nb_tr_errors) / tr_input.size(0), nb_tr_errors, tr_input.size(0)))
print('te error {:0.2f}% {:d}/{:d}'.format((100 * nb_te_errors) / te_input.size(0), nb_te_errors, te_input.size(0)))
# Out:
# epoch 0 tr loss 17.70 te loss 54.99
# epoch 1 tr loss 17.52 te loss 55.18
# epoch 2 tr loss 17.40 te loss 55.19
# epoch 3 tr loss 17.61 te loss 55.15
# epoch 4 tr loss 17.33 te loss 55.24
# epoch 5 tr loss 17.46 te loss 55.17
# epoch 6 tr loss 17.37 te loss 55.19
# epoch 7 tr loss 17.01 te loss 55.38
# epoch 8 tr loss 16.92 te loss 55.60
# epoch 9 tr loss 16.81 te loss 55.64
# epoch 10 tr loss 17.12 te loss 55.89
# epoch 11 tr loss 16.90 te loss 55.74
# epoch 12 tr loss 16.43 te loss 56.78
# epoch 13 tr loss 17.16 te loss 56.26
# epoch 14 tr loss 16.68 te loss 56.30
# epoch 15 tr loss 16.71 te loss 56.18
# epoch 16 tr loss 16.95 te loss 56.62
# epoch 17 tr loss 16.80 te loss 57.30
# epoch 18 tr loss 16.80 te loss 56.90
# epoch 19 tr loss 16.42 te loss 57.64
# epoch 20 tr loss 16.13 te loss 57.67
# epoch 21 tr loss 15.90 te loss 58.55
# epoch 22 tr loss 16.22 te loss 57.84
# epoch 23 tr loss 15.89 te loss 58.55
# epoch 24 tr loss 15.16 te loss 59.41
# epoch 25 tr loss 16.42 te loss 57.89
# epoch 26 tr loss 16.06 te loss 59.18
# epoch 27 tr loss 15.34 te loss 59.70
# epoch 28 tr loss 15.20 te loss 60.23
# epoch 29 tr loss 15.43 te loss 60.53
# epoch 30 tr loss 15.28 te loss 60.08
# epoch 31 tr loss 15.11 te loss 60.06
# epoch 32 tr loss 14.89 te loss 60.26
# epoch 33 tr loss 14.14 te loss 61.71
# epoch 34 tr loss 13.75 te loss 59.79
# epoch 35 tr loss 13.81 te loss 63.91
# epoch 36 tr loss 13.28 te loss 68.00
# epoch 37 tr loss 13.11 te loss 64.54
# epoch 38 tr loss 12.34 te loss 68.35
# epoch 39 tr loss 12.47 te loss 73.89
# epoch 40 tr loss 13.29 te loss 67.79
# epoch 41 tr loss 11.74 te loss 72.85
# epoch 42 tr loss 11.42 te loss 77.22
# epoch 43 tr loss 11.88 te loss 74.55
# epoch 44 tr loss 11.67 te loss 74.47
# epoch 45 tr loss 11.37 te loss 73.97
# epoch 46 tr loss 10.95 te loss 73.50
# epoch 47 tr loss 10.92 te loss 85.70
# epoch 48 tr loss 10.90 te loss 90.90
# epoch 49 tr loss 9.84 te loss 81.93
# epoch 50 tr loss 9.81 te loss 83.56
# epoch 51 tr loss 10.56 te loss 84.54
# epoch 52 tr loss 15.00 te loss 59.16
# epoch 53 tr loss 12.27 te loss 71.56
# epoch 54 tr loss 9.95 te loss 77.05
# epoch 55 tr loss 9.29 te loss 80.49
# epoch 56 tr loss 8.56 te loss 91.21
# epoch 57 tr loss 8.29 te loss 92.76
# epoch 58 tr loss 10.46 te loss 82.86
# epoch 59 tr loss 8.14 te loss 98.59
# epoch 60 tr loss 8.29 te loss 86.21
# epoch 61 tr loss 6.97 te loss 90.39
# epoch 62 tr loss 6.23 te loss 94.51
# epoch 63 tr loss 7.57 te loss 94.15
# epoch 64 tr loss 8.08 te loss 89.51
# epoch 65 tr loss 5.94 te loss 99.47
# epoch 66 tr loss 6.39 te loss 104.53
# epoch 67 tr loss 6.09 te loss 93.79
# epoch 68 tr loss 4.78 te loss 105.59
# epoch 69 tr loss 17.69 te loss 63.22
# epoch 70 tr loss 9.35 te loss 77.23
# epoch 71 tr loss 6.57 te loss 92.23
# epoch 72 tr loss 5.96 te loss 93.96
# epoch 73 tr loss 5.14 te loss 100.65
# epoch 74 tr loss 4.66 te loss 106.88
# epoch 75 tr loss 4.34 te loss 109.29
# epoch 76 tr loss 3.37 te loss 121.68
# epoch 77 tr loss 2.87 te loss 131.30
# epoch 78 tr loss 2.14 te loss 132.43
# epoch 79 tr loss 4.28 te loss 158.65
# epoch 80 tr loss 2.77 te loss 128.46
# epoch 81 tr loss 4.85 te loss 144.21
# epoch 82 tr loss 2.92 te loss 143.68
# epoch 83 tr loss 4.06 te loss 115.63
# epoch 84 tr loss 3.52 te loss 126.29
# epoch 85 tr loss 2.67 te loss 121.88
# epoch 86 tr loss 2.58 te loss 137.89
# epoch 87 tr loss 1.39 te loss 150.33
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-fa1a3ac4def2> in <module>()
#       1 # construct and train model
#       2 model = Net()
# ----> 3 tr_loss, te_loss = bci.train_model(model, te_input, te_target, 4, tr_input, tr_target, 4, 200)
#       4 #torch.save(model.state_dict(), os.getcwd() + "v1.pth")
#       5
#
# ~\Desktop\Haziq\EPFL\EE 559 - Deep Learning\projects\project1\haziq\dlc_bci.py in train_model(model, train_input, train_target, train_mini_batch_size, test_input, test_target, test_mini_batch_size, epoch)
#     116
#     117             # feedforward and compute loss
# --> 118             output = model(test_input.narrow(0, b, test_mini_batch_size), False)
#     119             loss = criterion(output, test_target.narrow(0, b, test_mini_batch_size))
#     120             te_loss = te_loss + loss.data[0]
#
# ~\Anaconda3\envs\dl\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
# --> 357             result = self.forward(*input, **kwargs)
#     358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#
# <ipython-input-11-f757fa5a32d3> in forward(self, x, mode)
#      32
#      33         # fc
# ---> 34         x = F.relu(self.fc1(x))
#      35         x = F.dropout(x, p=0.5, training=mode)
#      36         x = self.fc2(x)
#
# ~\Anaconda3\envs\dl\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
# --> 357             result = self.forward(*input, **kwargs)
#     358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#
# ~\Anaconda3\envs\dl\lib\site-packages\torch\nn\modules\linear.py in forward(self, input)
#      53
#      54     def forward(self, input):
# ---> 55         return F.linear(input, self.weight, self.bias)
#      56
#      57     def __repr__(self):
#
# ~\Anaconda3\envs\dl\lib\site-packages\torch\nn\functional.py in linear(input, weight, bias)
#     833     if input.dim() == 2 and bias is not None:
#     834         # fused op is marginally faster
# --> 835         return torch.addmm(bias, input, weight.t())
#     836
#     837     output = input.matmul(weight.t())
#
# KeyboardInterrupt:

# %%
import matplotlib as mpl
mpl.rcParams['figure.dpi']= 150

plt.figure()
plt.plot(tr_loss, label='training loss')
plt.plot(te_loss, label='validation loss')
plt.legend(loc='upper left')
